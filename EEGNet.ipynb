# %%
import mne
import numpy as np
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, DepthwiseConv2D, AveragePooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
import seaborn as sns
import matplotlib.pyplot as plt

# Data Loading and Preprocessing
base_path = r'C:\\Users\\karan\\Downloads\\EEG Data\\Data'
# Exclude A04 from the list of subjects
subjects = [f'A0{i}' for i in range(1, 10) if i != 4]
event_ids = [7, 8, 9, 10]  # Define event IDs for motor imagery tasks

all_features = []
all_labels = []

for subject in subjects:
    file_path = f'{base_path}\{subject}T.gdf'
    print(f"Processing {subject}...")
    raw = mne.io.read_raw_gdf(file_path, preload=True)
    raw.drop_channels(['EOG-left', 'EOG-central', 'EOG-right'])
    raw.set_eeg_reference()
    events, _ = mne.events_from_annotations(raw)
    epochs = mne.Epochs(raw, events, event_id=event_ids, on_missing='warn', preload=True)
    features = epochs.get_data()  # Shape: (n_epochs, n_channels, n_timepoints)
    labels = epochs.events[:, -1]  # Extract event IDs as labels
    all_features.append(features)
    all_labels.append(labels)

# Concatenate data across all subjects
features = np.concatenate(all_features, axis=0)
labels = np.concatenate(all_labels, axis=0)

# Normalize features (Z-score across all channels and timepoints)
scaler = StandardScaler()
features = scaler.fit_transform(features.reshape(features.shape[0], -1)).reshape(features.shape)

# Reshape features for CNN input (add channel dimension)
features = features[..., np.newaxis]  # Shape: (n_samples, n_channels, n_timepoints, 1)

# One-hot encode labels for multi-class classification
labels = to_categorical(labels - event_ids[0])  # Adjust labels to start from 0

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

# Print data shapes for verification
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")

# Build EEGNet Model
def build_eegnet(input_shape, num_classes):
    inputs = Input(shape=input_shape)
    
    # Temporal Convolution
    x = Conv2D(8, kernel_size=(1, 64), padding='same', activation='elu')(inputs)
    x = BatchNormalization()(x)
    
    # Depthwise Convolution
    x = DepthwiseConv2D((input_shape[0], 1), depth_multiplier=2, activation='elu')(x)
    x = BatchNormalization()(x)
    x = AveragePooling2D((1, 4))(x)
    x = Dropout(0.5)(x)
    
    # Separable Convolution
    x = Conv2D(16, kernel_size=(1, 16), padding='same', activation='elu')(x)
    x = BatchNormalization()(x)
    x = AveragePooling2D((1, 8))(x)
    x = Dropout(0.5)(x)
    
    # Fully Connected Layers
    x = Flatten()(x)
    outputs = Dense(num_classes, activation='softmax')(x)
    
    model = Model(inputs, outputs)
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# Define input shape and number of classes
input_shape = (features.shape[1], features.shape[2], 1)  # (n_channels, n_timepoints, 1)
num_classes = labels.shape[1]

# Build the EEGNet model
eegnet = build_eegnet(input_shape, num_classes)

# Print the model summary
eegnet.summary()

# Define callbacks
callbacks = [
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1)
]

# Train the model
history = eegnet.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=50,
    batch_size=32,
    callbacks=callbacks,
    verbose=1
)

# Evaluate the model on the test set
test_loss, test_accuracy = eegnet.evaluate(X_test, y_test, verbose=0)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")

# Predictions and Evaluation
y_pred_probs = eegnet.predict(X_test)  # Predicted probabilities
y_pred = np.argmax(y_pred_probs, axis=1)  # Predicted classes
y_test_classes = np.argmax(y_test, axis=1)  # True classes

# Classification Report
print("\nClassification Report:")
print(classification_report(y_test_classes, y_pred))

# Confusion Matrix
conf_matrix = confusion_matrix(y_test_classes, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=range(num_classes), yticklabels=range(num_classes))
plt.title('EEGNet Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# Plot Training History
# Accuracy Plot
plt.figure()
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('EEGNet Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Loss Plot
plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('EEGNet Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Compute ROC curve and AUC for each class
fpr = {}
tpr = {}
roc_auc = {}
for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Print ROC-AUC for each class
print("\nROC-AUC for each class:")
for i in range(num_classes):
    print(f"Class {i}: AUC = {roc_auc[i]:.2f}")

# Compute the average ROC-AUC across all classes
average_roc_auc = np.mean(list(roc_auc.values()))
print(f"\nAverage ROC-AUC: {average_roc_auc:.4f}")

# Plot ROC curve for each class
plt.figure(figsize=(10, 8))
for i in range(num_classes):
    plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.title('EEGNet ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()
# Out:
# <string>:23: SyntaxWarning: invalid escape sequence '\{'
# <>:23: SyntaxWarning: invalid escape sequence '\{'
# <string>:23: SyntaxWarning: invalid escape sequence '\{'
# <>:23: SyntaxWarning: invalid escape sequence '\{'
# C:\Users\karan\AppData\Local\Temp\ipykernel_29716\1206826157.py:23: SyntaxWarning: invalid escape sequence '\{'
#   file_path = f'{base_path}\{subject}T.gdf'
# Processing A01...
# Extracting EDF parameters from C:\Users\karan\Downloads\EEG Data\Data\A01T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG, EOG-left, EOG-central, EOG-right
# Creating raw.info structure...
# c:\Users\karan\anaconda3\Lib\contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Reading 0 ... 672527  =      0.000 ...  2690.108 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Used Annotations descriptions: ['1023', '1072', '276', '277', '32766', '768', '769', '770', '771', '772']
# Not setting metadata
# 288 matching events found
# Setting baseline interval to [-0.2, 0.0] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 288 events and 176 original time points ...
# 0 bad epochs dropped
# Processing A02...
# Extracting EDF parameters from C:\Users\karan\Downloads\EEG Data\Data\A02T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG, EOG-left, EOG-central, EOG-right
# Creating raw.info structure...
# Reading 0 ... 677168  =      0.000 ...  2708.672 secs...
# c:\Users\karan\anaconda3\Lib\contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Used Annotations descriptions: ['1023', '1072', '276', '277', '32766', '768', '769', '770', '771', '772']
# Not setting metadata
# 288 matching events found
# Setting baseline interval to [-0.2, 0.0] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 288 events and 176 original time points ...
# 0 bad epochs dropped
# Processing A03...
# Extracting EDF parameters from C:\Users\karan\Downloads\EEG Data\Data\A03T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG, EOG-left, EOG-central, EOG-right
# Creating raw.info structure...
# Reading 0 ... 660529  =      0.000 ...  2642.116 secs...
# c:\Users\karan\anaconda3\Lib\contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Used Annotations descriptions: ['1023', '1072', '276', '277', '32766', '768', '769', '770', '771', '772']
# Not setting metadata
# 288 matching events found
# Setting baseline interval to [-0.2, 0.0] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 288 events and 176 original time points ...
# 0 bad epochs dropped
# Processing A05...
# Extracting EDF parameters from C:\Users\karan\Downloads\EEG Data\Data\A05T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG, EOG-left, EOG-central, EOG-right
# Creating raw.info structure...
# Reading 0 ... 686119  =      0.000 ...  2744.476 secs...
# c:\Users\karan\anaconda3\Lib\contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Used Annotations descriptions: ['1023', '1072', '276', '277', '32766', '768', '769', '770', '771', '772']
# Not setting metadata
# 288 matching events found
# Setting baseline interval to [-0.2, 0.0] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 288 events and 176 original time points ...
# 0 bad epochs dropped
# Processing A06...
# Extracting EDF parameters from C:\Users\karan\Downloads\EEG Data\Data\A06T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG, EOG-left, EOG-central, EOG-right
# Creating raw.info structure...
# Reading 0 ... 678979  =      0.000 ...  2715.916 secs...
# c:\Users\karan\anaconda3\Lib\contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Used Annotations descriptions: ['1023', '1072', '276', '277', '32766', '768', '769', '770', '771', '772']
# Not setting metadata
# 288 matching events found
# Setting baseline interval to [-0.2, 0.0] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 288 events and 176 original time points ...
# 0 bad epochs dropped
# Processing A07...
# Extracting EDF parameters from C:\Users\karan\Downloads\EEG Data\Data\A07T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG, EOG-left, EOG-central, EOG-right
# Creating raw.info structure...
# Reading 0 ... 681070  =      0.000 ...  2724.280 secs...
# c:\Users\karan\anaconda3\Lib\contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Used Annotations descriptions: ['1023', '1072', '276', '277', '32766', '768', '769', '770', '771', '772']
# Not setting metadata
# 288 matching events found
# Setting baseline interval to [-0.2, 0.0] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 288 events and 176 original time points ...
# 0 bad epochs dropped
# Processing A08...
# Extracting EDF parameters from C:\Users\karan\Downloads\EEG Data\Data\A08T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG, EOG-left, EOG-central, EOG-right
# Creating raw.info structure...
# Reading 0 ... 675269  =      0.000 ...  2701.076 secs...
# c:\Users\karan\anaconda3\Lib\contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Used Annotations descriptions: ['1023', '1072', '276', '277', '32766', '768', '769', '770', '771', '772']
# Not setting metadata
# 288 matching events found
# Setting baseline interval to [-0.2, 0.0] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 288 events and 176 original time points ...
# 0 bad epochs dropped
# Processing A09...
# Extracting EDF parameters from C:\Users\karan\Downloads\EEG Data\Data\A09T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG, EOG-left, EOG-central, EOG-right
# Creating raw.info structure...
# Reading 0 ... 673327  =      0.000 ...  2693.308 secs...
# c:\Users\karan\anaconda3\Lib\contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Used Annotations descriptions: ['1023', '1072', '276', '277', '32766', '768', '769', '770', '771', '772']
# Not setting metadata
# 288 matching events found
# Setting baseline interval to [-0.2, 0.0] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 288 events and 176 original time points ...
# 0 bad epochs dropped
# X_train shape: (1843, 22, 176, 1), y_train shape: (1843, 4)
# X_test shape: (461, 22, 176, 1), y_test shape: (461, 4)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 22, 176, 1)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 22, 176, 8)     │           520 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 22, 176, 8)     │            32 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ depthwise_conv2d                │ (None, 1, 176, 16)     │           368 │
# │ (DepthwiseConv2D)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 1, 176, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d               │ (None, 1, 44, 16)      │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1, 44, 16)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 1, 44, 16)      │         4,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 1, 44, 16)      │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_1             │ (None, 1, 5, 16)       │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 1, 5, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 80)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 4)              │           324 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,484 (21.42 KB)
#  Trainable params: 5,404 (21.11 KB)
#  Non-trainable params: 80 (320.00 B)
# Epoch 1/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 43ms/step - accuracy: 0.2662 - loss: 1.5744 - val_accuracy: 0.2907 - val_loss: 1.3705 - learning_rate: 0.0010
# Epoch 2/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.3148 - loss: 1.4365 - val_accuracy: 0.3015 - val_loss: 1.3600 - learning_rate: 0.0010
# Epoch 3/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.3639 - loss: 1.3507 - val_accuracy: 0.3579 - val_loss: 1.3286 - learning_rate: 0.0010
# Epoch 4/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.3983 - loss: 1.3125 - val_accuracy: 0.4013 - val_loss: 1.2924 - learning_rate: 0.0010
# Epoch 5/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.3801 - loss: 1.2995 - val_accuracy: 0.4620 - val_loss: 1.2600 - learning_rate: 0.0010
# Epoch 6/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.4149 - loss: 1.2658 - val_accuracy: 0.4447 - val_loss: 1.2386 - learning_rate: 0.0010
# Epoch 7/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.4488 - loss: 1.2372 - val_accuracy: 0.4425 - val_loss: 1.2274 - learning_rate: 0.0010
# Epoch 8/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.4564 - loss: 1.2155 - val_accuracy: 0.4751 - val_loss: 1.2053 - learning_rate: 0.0010
# Epoch 9/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.4455 - loss: 1.2058 - val_accuracy: 0.4837 - val_loss: 1.1973 - learning_rate: 0.0010
# Epoch 10/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.4703 - loss: 1.1785 - val_accuracy: 0.5076 - val_loss: 1.1755 - learning_rate: 0.0010
# Epoch 11/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.4910 - loss: 1.1797 - val_accuracy: 0.4967 - val_loss: 1.1722 - learning_rate: 0.0010
# Epoch 12/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.4821 - loss: 1.1589 - val_accuracy: 0.4946 - val_loss: 1.1643 - learning_rate: 0.0010
# Epoch 13/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.4985 - loss: 1.1690 - val_accuracy: 0.5054 - val_loss: 1.1680 - learning_rate: 0.0010
# Epoch 14/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - accuracy: 0.4869 - loss: 1.1565 - val_accuracy: 0.5249 - val_loss: 1.1594 - learning_rate: 0.0010
# Epoch 15/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.4938 - loss: 1.1422 - val_accuracy: 0.5033 - val_loss: 1.1550 - learning_rate: 0.0010
# Epoch 16/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 109ms/step - accuracy: 0.5094 - loss: 1.1620 - val_accuracy: 0.5249 - val_loss: 1.1447 - learning_rate: 0.0010
# Epoch 17/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 88ms/step - accuracy: 0.4767 - loss: 1.1807 - val_accuracy: 0.5271 - val_loss: 1.1403 - learning_rate: 0.0010
# Epoch 18/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 7s 104ms/step - accuracy: 0.5143 - loss: 1.1320 - val_accuracy: 0.5249 - val_loss: 1.1348 - learning_rate: 0.0010
# Epoch 19/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 7s 107ms/step - accuracy: 0.5017 - loss: 1.1161 - val_accuracy: 0.5141 - val_loss: 1.1346 - learning_rate: 0.0010
# Epoch 20/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 7s 112ms/step - accuracy: 0.5174 - loss: 1.1306 - val_accuracy: 0.5293 - val_loss: 1.1272 - learning_rate: 0.0010
# Epoch 21/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 7s 101ms/step - accuracy: 0.5266 - loss: 1.1149 - val_accuracy: 0.5228 - val_loss: 1.1250 - learning_rate: 0.0010
# Epoch 22/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - accuracy: 0.5338 - loss: 1.0929 - val_accuracy: 0.5184 - val_loss: 1.1293 - learning_rate: 0.0010
# Epoch 23/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.5326 - loss: 1.1031 - val_accuracy: 0.5249 - val_loss: 1.1288 - learning_rate: 0.0010
# Epoch 24/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.5486 - loss: 1.0800 - val_accuracy: 0.5531 - val_loss: 1.1242 - learning_rate: 0.0010
# Epoch 25/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.5409 - loss: 1.0579 - val_accuracy: 0.5336 - val_loss: 1.1098 - learning_rate: 0.0010
# Epoch 26/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.5139 - loss: 1.0893 - val_accuracy: 0.5249 - val_loss: 1.1232 - learning_rate: 0.0010
# Epoch 27/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 7s 112ms/step - accuracy: 0.5593 - loss: 1.0768 - val_accuracy: 0.5401 - val_loss: 1.1197 - learning_rate: 0.0010
# Epoch 28/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 7s 121ms/step - accuracy: 0.5173 - loss: 1.0963 - val_accuracy: 0.5423 - val_loss: 1.1118 - learning_rate: 0.0010
# Epoch 29/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 7s 107ms/step - accuracy: 0.5319 - loss: 1.0809 - val_accuracy: 0.5315 - val_loss: 1.1191 - learning_rate: 0.0010
# Epoch 30/50
# 57/58 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.5279 - loss: 1.0467
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 96ms/step - accuracy: 0.5281 - loss: 1.0475 - val_accuracy: 0.5228 - val_loss: 1.1168 - learning_rate: 0.0010
# Epoch 31/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.5625 - loss: 1.0490 - val_accuracy: 0.5271 - val_loss: 1.1057 - learning_rate: 5.0000e-04
# Epoch 32/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.5338 - loss: 1.0719 - val_accuracy: 0.5271 - val_loss: 1.1050 - learning_rate: 5.0000e-04
# Epoch 33/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.5630 - loss: 1.0339 - val_accuracy: 0.5380 - val_loss: 1.1053 - learning_rate: 5.0000e-04
# Epoch 34/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.5622 - loss: 1.0457 - val_accuracy: 0.5141 - val_loss: 1.1075 - learning_rate: 5.0000e-04
# Epoch 35/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.5622 - loss: 1.0396 - val_accuracy: 0.5163 - val_loss: 1.1067 - learning_rate: 5.0000e-04
# Epoch 36/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - accuracy: 0.5551 - loss: 1.0681 - val_accuracy: 0.5163 - val_loss: 1.1039 - learning_rate: 5.0000e-04
# Epoch 37/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.5570 - loss: 1.0476 - val_accuracy: 0.5206 - val_loss: 1.1077 - learning_rate: 5.0000e-04
# Epoch 38/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.5735 - loss: 1.0289 - val_accuracy: 0.5380 - val_loss: 1.1071 - learning_rate: 5.0000e-04
# Epoch 39/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.5729 - loss: 1.0260 - val_accuracy: 0.5380 - val_loss: 1.1039 - learning_rate: 5.0000e-04
# Epoch 40/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.5490 - loss: 1.0278 - val_accuracy: 0.5336 - val_loss: 1.1048 - learning_rate: 5.0000e-04
# Epoch 41/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - accuracy: 0.5665 - loss: 1.0324 - val_accuracy: 0.5336 - val_loss: 1.0999 - learning_rate: 5.0000e-04
# Epoch 42/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.5757 - loss: 0.9992 - val_accuracy: 0.5293 - val_loss: 1.1124 - learning_rate: 5.0000e-04
# Epoch 43/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.5500 - loss: 1.0333 - val_accuracy: 0.5401 - val_loss: 1.1065 - learning_rate: 5.0000e-04
# Epoch 44/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - accuracy: 0.5722 - loss: 1.0251 - val_accuracy: 0.5358 - val_loss: 1.1191 - learning_rate: 5.0000e-04
# Epoch 45/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - accuracy: 0.5762 - loss: 1.0285 - val_accuracy: 0.5358 - val_loss: 1.1147 - learning_rate: 5.0000e-04
# Epoch 46/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5795 - loss: 1.0518
# Epoch 46: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.5794 - loss: 1.0515 - val_accuracy: 0.5380 - val_loss: 1.1061 - learning_rate: 5.0000e-04
# Epoch 47/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.5615 - loss: 1.0107 - val_accuracy: 0.5293 - val_loss: 1.1107 - learning_rate: 2.5000e-04
# Epoch 48/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.5476 - loss: 1.0478 - val_accuracy: 0.5293 - val_loss: 1.1075 - learning_rate: 2.5000e-04
# Epoch 49/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.5792 - loss: 1.0251 - val_accuracy: 0.5315 - val_loss: 1.1088 - learning_rate: 2.5000e-04
# Epoch 50/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - accuracy: 0.5720 - loss: 1.0009 - val_accuracy: 0.5315 - val_loss: 1.1097 - learning_rate: 2.5000e-04
# Restoring model weights from the end of the best epoch: 41.
# Test Accuracy: 53.36%
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.55      0.66      0.60       122
#            1       0.53      0.51      0.52       116
#            2       0.57      0.45      0.50       114
#            3       0.49      0.51      0.50       109
#
#     accuracy                           0.53       461
#    macro avg       0.53      0.53      0.53       461
# weighted avg       0.53      0.53      0.53       461
# ROC-AUC for each class:
# Class 0: AUC = 0.81
# Class 1: AUC = 0.77
# Class 2: AUC = 0.81
# Class 3: AUC = 0.76
#
# Average ROC-AUC: 0.7855

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Prepare labels for Stratified K-Fold (convert one-hot encoding to class indices)
y_labels = np.argmax(labels, axis=1)

# Initialize Stratified K-Fold
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

fold = 1
accuracy_per_fold = []
loss_per_fold = []
roc_auc_per_fold = []
all_classification_reports = []
all_confusion_matrices = []

for train_index, test_index in kf.split(features, y_labels):
    print(f"\nTraining Fold {fold}...")
    X_train, X_test = features[train_index], features[test_index]
    y_train, y_test = labels[train_index], labels[test_index]

    # Build a new EEGNet model for each fold
    model = build_eegnet(input_shape, num_classes)

    # Train the model
    history = model.fit(
        X_train, y_train,
        validation_data=(X_test, y_test),
        epochs=10,
        batch_size=32,
        verbose=1,
        callbacks=callbacks
    )

    # Evaluate the model
    val_loss, val_accuracy = model.evaluate(X_test, y_test, verbose=0)
    accuracy_per_fold.append(val_accuracy)
    loss_per_fold.append(val_loss)
    print(f"Fold {fold} Accuracy: {val_accuracy * 100:.2f}%")
    print(f"Fold {fold} Loss: {val_loss:.4f}")

    # Predictions and ROC-AUC
    y_pred_probs = model.predict(X_test)
    y_pred = np.argmax(y_pred_probs, axis=1)
    y_test_classes = np.argmax(y_test, axis=1)

    # Compute ROC-AUC for each class
    fpr, tpr, roc_auc = {}, {}, {}
    for i in range(num_classes):
        fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred_probs[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])
    avg_roc_auc = np.mean(list(roc_auc.values()))
    roc_auc_per_fold.append(avg_roc_auc)
    print(f"Fold {fold} Average ROC-AUC: {avg_roc_auc:.4f}")

    # Classification Report
    report = classification_report(y_test_classes, y_pred, target_names=[f"Class {i}" for i in range(num_classes)])
    all_classification_reports.append(report)

    # Confusion Matrix
    conf_matrix = confusion_matrix(y_test_classes, y_pred)
    all_confusion_matrices.append(conf_matrix)

    print("\nClassification Report:")
    print(report)

    # Plot Confusion Matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
                xticklabels=[f"Class {i}" for i in range(num_classes)],
                yticklabels=[f"Class {i}" for i in range(num_classes)])
    plt.title(f"Confusion Matrix - Fold {fold}")
    plt.xlabel("Predicted Labels")
    plt.ylabel("True Labels")
    plt.show()

    fold += 1

# Final Cross-Validation Results
print("\nCross-Validation Results:")
print(f"Average Accuracy: {np.mean(accuracy_per_fold) * 100:.2f}%")
print(f"Standard Deviation of Accuracy: {np.std(accuracy_per_fold) * 100:.2f}%")
print(f"Average Loss: {np.mean(loss_per_fold):.4f}")
print(f"Standard Deviation of Loss: {np.std(loss_per_fold):.4f}")
print(f"Average ROC-AUC: {np.mean(roc_auc_per_fold):.4f}")
print(f"Standard Deviation of ROC-AUC: {np.std(roc_auc_per_fold):.4f}")
# Out:
# Training Fold 1...
# Epoch 1/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - accuracy: 0.2914 - loss: 1.5403 - val_accuracy: 0.3124 - val_loss: 1.3628 - learning_rate: 0.0010
# Epoch 2/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.2974 - loss: 1.4487 - val_accuracy: 0.3666 - val_loss: 1.3412 - learning_rate: 0.0010
# Epoch 3/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.3467 - loss: 1.3713 - val_accuracy: 0.4078 - val_loss: 1.3159 - learning_rate: 0.0010
# Epoch 4/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.4071 - loss: 1.3057 - val_accuracy: 0.4317 - val_loss: 1.2889 - learning_rate: 0.0010
# Epoch 5/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.4148 - loss: 1.3063 - val_accuracy: 0.4252 - val_loss: 1.2643 - learning_rate: 0.0010
# Epoch 6/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.4371 - loss: 1.2435 - val_accuracy: 0.4577 - val_loss: 1.2418 - learning_rate: 0.0010
# Epoch 7/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.4182 - loss: 1.2428 - val_accuracy: 0.4837 - val_loss: 1.2192 - learning_rate: 0.0010
# Epoch 8/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.4586 - loss: 1.2148 - val_accuracy: 0.4772 - val_loss: 1.1909 - learning_rate: 0.0010
# Epoch 9/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.4693 - loss: 1.2167 - val_accuracy: 0.4772 - val_loss: 1.1703 - learning_rate: 0.0010
# Epoch 10/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.4732 - loss: 1.2048 - val_accuracy: 0.4859 - val_loss: 1.1635 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 10.
# Fold 1 Accuracy: 48.59%
# Fold 1 Loss: 1.1635
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Fold 1 Average ROC-AUC: 0.7568
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Class 0       0.46      0.44      0.45       115
#      Class 1       0.50      0.61      0.55       115
#      Class 2       0.51      0.47      0.49       115
#      Class 3       0.47      0.42      0.44       116
#
#     accuracy                           0.49       461
#    macro avg       0.48      0.49      0.48       461
# weighted avg       0.48      0.49      0.48       461
# Training Fold 2...
# Epoch 1/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - accuracy: 0.2919 - loss: 1.5691 - val_accuracy: 0.3536 - val_loss: 1.3545 - learning_rate: 0.0010
# Epoch 2/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.3276 - loss: 1.4109 - val_accuracy: 0.3861 - val_loss: 1.3345 - learning_rate: 0.0010
# Epoch 3/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.3637 - loss: 1.3459 - val_accuracy: 0.3839 - val_loss: 1.3155 - learning_rate: 0.0010
# Epoch 4/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.3666 - loss: 1.3405 - val_accuracy: 0.4295 - val_loss: 1.2744 - learning_rate: 0.0010
# Epoch 5/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.4162 - loss: 1.2795 - val_accuracy: 0.4837 - val_loss: 1.2372 - learning_rate: 0.0010
# Epoch 6/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.4003 - loss: 1.2923 - val_accuracy: 0.4881 - val_loss: 1.2022 - learning_rate: 0.0010
# Epoch 7/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.4482 - loss: 1.2433 - val_accuracy: 0.5119 - val_loss: 1.1653 - learning_rate: 0.0010
# Epoch 8/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.4770 - loss: 1.1975 - val_accuracy: 0.5076 - val_loss: 1.1469 - learning_rate: 0.0010
# Epoch 9/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.4811 - loss: 1.2063 - val_accuracy: 0.5401 - val_loss: 1.1307 - learning_rate: 0.0010
# Epoch 10/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.5294 - loss: 1.1451 - val_accuracy: 0.5293 - val_loss: 1.1163 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 10.
# Fold 2 Accuracy: 52.93%
# Fold 2 Loss: 1.1163
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Fold 2 Average ROC-AUC: 0.7842
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Class 0       0.53      0.59      0.56       115
#      Class 1       0.51      0.63      0.56       115
#      Class 2       0.48      0.45      0.46       116
#      Class 3       0.63      0.45      0.53       115
#
#     accuracy                           0.53       461
#    macro avg       0.54      0.53      0.53       461
# weighted avg       0.54      0.53      0.53       461
# Training Fold 3...
# Epoch 1/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - accuracy: 0.2754 - loss: 1.5303 - val_accuracy: 0.3427 - val_loss: 1.3645 - learning_rate: 0.0010
# Epoch 2/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.3154 - loss: 1.4249 - val_accuracy: 0.4035 - val_loss: 1.3241 - learning_rate: 0.0010
# Epoch 3/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.3714 - loss: 1.3497 - val_accuracy: 0.4490 - val_loss: 1.2906 - learning_rate: 0.0010
# Epoch 4/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.4175 - loss: 1.2792 - val_accuracy: 0.4599 - val_loss: 1.2540 - learning_rate: 0.0010
# Epoch 5/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.4121 - loss: 1.2449 - val_accuracy: 0.4859 - val_loss: 1.2125 - learning_rate: 0.0010
# Epoch 6/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.4765 - loss: 1.1806 - val_accuracy: 0.4707 - val_loss: 1.1928 - learning_rate: 0.0010
# Epoch 7/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.4833 - loss: 1.1755 - val_accuracy: 0.4902 - val_loss: 1.1748 - learning_rate: 0.0010
# Epoch 8/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.4688 - loss: 1.1761 - val_accuracy: 0.4685 - val_loss: 1.1798 - learning_rate: 0.0010
# Epoch 9/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.5094 - loss: 1.1555 - val_accuracy: 0.4967 - val_loss: 1.1671 - learning_rate: 0.0010
# Epoch 10/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.4743 - loss: 1.1395 - val_accuracy: 0.4989 - val_loss: 1.1569 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 10.
# Fold 3 Accuracy: 49.89%
# Fold 3 Loss: 1.1569
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Fold 3 Average ROC-AUC: 0.7602
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Class 0       0.49      0.70      0.57       115
#      Class 1       0.48      0.66      0.56       116
#      Class 2       0.51      0.36      0.42       115
#      Class 3       0.57      0.28      0.37       115
#
#     accuracy                           0.50       461
#    macro avg       0.51      0.50      0.48       461
# weighted avg       0.51      0.50      0.48       461
# Training Fold 4...
# Epoch 1/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - accuracy: 0.2656 - loss: 1.5742 - val_accuracy: 0.3102 - val_loss: 1.3675 - learning_rate: 0.0010
# Epoch 2/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.2978 - loss: 1.4550 - val_accuracy: 0.3471 - val_loss: 1.3403 - learning_rate: 0.0010
# Epoch 3/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.3459 - loss: 1.3766 - val_accuracy: 0.3818 - val_loss: 1.3131 - learning_rate: 0.0010
# Epoch 4/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.3569 - loss: 1.3404 - val_accuracy: 0.3991 - val_loss: 1.2790 - learning_rate: 0.0010
# Epoch 5/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.3740 - loss: 1.3247 - val_accuracy: 0.4252 - val_loss: 1.2507 - learning_rate: 0.0010
# Epoch 6/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.4266 - loss: 1.2716 - val_accuracy: 0.4729 - val_loss: 1.2169 - learning_rate: 0.0010
# Epoch 7/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.4348 - loss: 1.2328 - val_accuracy: 0.4881 - val_loss: 1.1844 - learning_rate: 0.0010
# Epoch 8/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.4421 - loss: 1.2389 - val_accuracy: 0.4772 - val_loss: 1.1673 - learning_rate: 0.0010
# Epoch 9/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.4733 - loss: 1.2143 - val_accuracy: 0.4859 - val_loss: 1.1590 - learning_rate: 0.0010
# Epoch 10/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.4560 - loss: 1.1928 - val_accuracy: 0.4859 - val_loss: 1.1626 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 9.
# Fold 4 Accuracy: 48.59%
# Fold 4 Loss: 1.1590
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step
# Fold 4 Average ROC-AUC: 0.7579
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Class 0       0.49      0.61      0.54       116
#      Class 1       0.52      0.59      0.55       115
#      Class 2       0.45      0.36      0.40       115
#      Class 3       0.47      0.38      0.42       115
#
#     accuracy                           0.49       461
#    macro avg       0.48      0.49      0.48       461
# weighted avg       0.48      0.49      0.48       461
# Training Fold 5...
# Epoch 1/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - accuracy: 0.2595 - loss: 1.5766 - val_accuracy: 0.3261 - val_loss: 1.3676 - learning_rate: 0.0010
# Epoch 2/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.3101 - loss: 1.4225 - val_accuracy: 0.3217 - val_loss: 1.3581 - learning_rate: 0.0010
# Epoch 3/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.3489 - loss: 1.3762 - val_accuracy: 0.3696 - val_loss: 1.3334 - learning_rate: 0.0010
# Epoch 4/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.3715 - loss: 1.3269 - val_accuracy: 0.4065 - val_loss: 1.3075 - learning_rate: 0.0010
# Epoch 5/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.4017 - loss: 1.3008 - val_accuracy: 0.4065 - val_loss: 1.2823 - learning_rate: 0.0010
# Epoch 6/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.4016 - loss: 1.2745 - val_accuracy: 0.4239 - val_loss: 1.2626 - learning_rate: 0.0010
# Epoch 7/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.4337 - loss: 1.2401 - val_accuracy: 0.4565 - val_loss: 1.2373 - learning_rate: 0.0010
# Epoch 8/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.4650 - loss: 1.2184 - val_accuracy: 0.4696 - val_loss: 1.2104 - learning_rate: 0.0010
# Epoch 9/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.4518 - loss: 1.2142 - val_accuracy: 0.4696 - val_loss: 1.2088 - learning_rate: 0.0010
# Epoch 10/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.4715 - loss: 1.1938 - val_accuracy: 0.4783 - val_loss: 1.1947 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 10.
# Fold 5 Accuracy: 47.83%
# Fold 5 Loss: 1.1947
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Fold 5 Average ROC-AUC: 0.7331
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Class 0       0.53      0.61      0.56       115
#      Class 1       0.38      0.31      0.34       115
#      Class 2       0.44      0.48      0.46       115
#      Class 3       0.56      0.51      0.54       115
#
#     accuracy                           0.48       460
#    macro avg       0.47      0.48      0.47       460
# weighted avg       0.47      0.48      0.47       460
# Cross-Validation Results:
# Average Accuracy: 49.57%
# Standard Deviation of Accuracy: 1.81%
# Average Loss: 1.1581
# Standard Deviation of Loss: 0.0250
# Average ROC-AUC: 0.7584
# Standard Deviation of ROC-AUC: 0.0162
