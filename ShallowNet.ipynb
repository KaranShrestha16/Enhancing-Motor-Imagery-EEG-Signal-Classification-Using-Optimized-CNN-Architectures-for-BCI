# %%
import mne
import numpy as np
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize

# Data Loading and Preprocessing
base_path = r'C:\\Users\\karan\\Downloads\\EEG Data\\Data'
# Exclude A04 from the list of subjects
subjects = [f'A0{i}' for i in range(1, 10) if i != 4]
event_ids = [7, 8, 9, 10]  # Define event IDs for motor imagery tasks

all_features = []
all_labels = []

for subject in subjects:
    file_path = f'{base_path}\\{subject}T.gdf'
    print(f"Processing {subject}...")
    raw = mne.io.read_raw_gdf(file_path, preload=True)
    raw.drop_channels(['EOG-left', 'EOG-central', 'EOG-right'])
    raw.set_eeg_reference()
    events, _ = mne.events_from_annotations(raw)
    epochs = mne.Epochs(raw, events, event_id=event_ids, on_missing='warn', preload=True)
    features = epochs.get_data()  # Shape: (n_epochs, n_channels, n_timepoints)
    labels = epochs.events[:, -1]  # Extract event IDs as labels
    all_features.append(features)
    all_labels.append(labels)

# Concatenate data across all subjects
features = np.concatenate(all_features, axis=0)
labels = np.concatenate(all_labels, axis=0)

# Normalize features (Z-score across all channels and timepoints)
scaler = StandardScaler()
features = scaler.fit_transform(features.reshape(features.shape[0], -1)).reshape(features.shape)

# Reshape features for CNN input (add channel dimension)
features = features[..., np.newaxis]  # Shape: (n_samples, n_channels, n_timepoints, 1)

# One-hot encode labels for multi-class classification
labels = to_categorical(labels - event_ids[0])  # Adjust labels to start from 0

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

# Print data shapes for verification
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")

# Build ShallowNet Model
def build_shallownet(input_shape, num_classes):
    model = Sequential()
    
    # 1st Convolutional Block
    model.add(Conv2D(16, (1, 10), activation='relu', input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((1, 3)))
    
    # 2nd Convolutional Block
    model.add(Conv2D(32, (1, 10), activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((1, 3)))
    
    # Fully Connected Layers
    model.add(Flatten())
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes, activation='softmax'))
    
    # Compile the model
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    
    return model

# Define input shape and number of classes
input_shape = (features.shape[1], features.shape[2], 1)  # (n_channels, n_timepoints, 1)
num_classes = labels.shape[1]

# Build the model
shallownet = build_shallownet(input_shape, num_classes)

# Print the model summary
shallownet.summary()

# Define callbacks
callbacks = [
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1)
]

# Train the model
history = shallownet.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),  # Use the test set as validation
    epochs=50,
    batch_size=32,
    callbacks=callbacks,
    verbose=1
)

# Evaluate the model on the test set
test_loss, test_accuracy = shallownet.evaluate(X_test, y_test, verbose=0)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")

# Predictions and Evaluation
y_pred_probs = shallownet.predict(X_test)  # Predicted probabilities
y_pred = np.argmax(y_pred_probs, axis=1)  # Predicted classes
y_test_classes = np.argmax(y_test, axis=1)  # True classes

# Classification Report
print("\nClassification Report:")
print(classification_report(y_test_classes, y_pred))

# Confusion Matrix
conf_matrix = confusion_matrix(y_test_classes, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=range(num_classes), yticklabels=range(num_classes))
plt.title('ShallowNet Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# Plot Training History
# Accuracy Plot
plt.figure()
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('ShallowNet Model Validaiton Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Loss Plot
plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('ShallowNet Model Validaiton Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()



# Compute ROC curve and AUC for each class
fpr = {}
tpr = {}
roc_auc = {}

# Binarize the true labels for multi-class ROC-AUC computation
y_test_binarized = label_binarize(y_test_classes, classes=range(num_classes))

# Compute ROC and AUC for each class
for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_binarized[:, i], y_pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Print ROC-AUC for each class
print("\nROC-AUC for each class:")
for i in range(num_classes):
    print(f"Class {i}: AUC = {roc_auc[i]:.4f}")

# Compute the average ROC-AUC across all classes
average_roc_auc = np.mean(list(roc_auc.values()))
print(f"\nAverage ROC-AUC: {average_roc_auc:.4f}")

# Plot ROC curves for each class
plt.figure(figsize=(10, 8))
for i in range(num_classes):
    plt.plot(fpr[i], tpr[i], label=f"Class {i} (AUC = {roc_auc[i]:.2f})")
plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.title('ShalloNet ROC Curve for Multi-Class Classification')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.grid()
plt.show()

# %%
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.models import clone_model
from sklearn.metrics import roc_curve, auc
import numpy as np

# Convert one-hot labels to single-label integers for StratifiedKFold
labels_integers = np.argmax(labels, axis=1)

# Parameters for Stratified Cross-Validation
num_folds = 5
skf = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)
fold_no = 1

# Store results
accuracy_per_fold = []
loss_per_fold = []
roc_auc_per_fold = []

# StratifiedKFold Cross-Validation
for train_idx, val_idx in skf.split(features, labels_integers):
    print(f"\nTraining Fold {fold_no}/{num_folds}")
    
    # Split data into training and validation sets
    X_train, X_val = features[train_idx], features[val_idx]
    y_train, y_val = labels[train_idx], labels[val_idx]
    
    # Build a new model instance for each fold
    model = build_shallownet(input_shape, num_classes)
    
    # Train the model
    history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=50,
        batch_size=32,
        callbacks=[
            EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1),
            ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1)
        ],
        verbose=1
    )
    
    # Evaluate the model on validation data
    val_loss, val_accuracy = model.evaluate(X_val, y_val, verbose=0)
    print(f"Fold {fold_no} - Validation Accuracy: {val_accuracy * 100:.2f}%")
    
    # Store validation accuracy and loss
    accuracy_per_fold.append(val_accuracy)
    loss_per_fold.append(val_loss)
    
    # Compute ROC-AUC for each class
    y_pred_probs = model.predict(X_val)
    fpr, tpr, roc_auc = {}, {}, {}
    for i in range(num_classes):
        fpr[i], tpr[i], _ = roc_curve(y_val[:, i], y_pred_probs[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])
    
    # Calculate average ROC-AUC for the fold
    avg_roc_auc = np.mean(list(roc_auc.values()))
    roc_auc_per_fold.append(avg_roc_auc)
    print(f"Fold {fold_no} - Average ROC-AUC: {avg_roc_auc:.4f}")
    
    # Increment fold number
    fold_no += 1

# Final Cross-Validation Results
print("\nCross-Validation Results:")
print(f"Average Accuracy: {np.mean(accuracy_per_fold) * 100:.2f}%")
print(f"Standard Deviation of Accuracy: {np.std(accuracy_per_fold) * 100:.2f}%")
print(f"Average Loss: {np.mean(loss_per_fold):.4f}")
print(f"Standard Deviation of Loss: {np.std(loss_per_fold):.4f}")
print(f"Average ROC-AUC: {np.mean(roc_auc_per_fold):.4f}")
print(f"Standard Deviation of ROC-AUC: {np.std(roc_auc_per_fold):.4f}")
# Out:
# Training Fold 1/5
# c:\Users\karan\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.2645 - loss: 2.1739 - val_accuracy: 0.3145 - val_loss: 1.6377 - learning_rate: 0.0010
# Epoch 2/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.2607 - loss: 1.3828 - val_accuracy: 0.3080 - val_loss: 2.6596 - learning_rate: 0.0010
# Epoch 3/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.2807 - loss: 1.3755 - val_accuracy: 0.2972 - val_loss: 3.2734 - learning_rate: 0.0010
# Epoch 4/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.2828 - loss: 1.3668 - val_accuracy: 0.3232 - val_loss: 2.9713 - learning_rate: 0.0010
# Epoch 5/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.2963 - loss: 1.3696 - val_accuracy: 0.3015 - val_loss: 2.2976 - learning_rate: 0.0010
# Epoch 6/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.2806 - loss: 1.3344
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.2809 - loss: 1.3343 - val_accuracy: 0.3492 - val_loss: 1.7530 - learning_rate: 0.0010
# Epoch 7/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.3321 - loss: 1.3092 - val_accuracy: 0.3059 - val_loss: 1.5882 - learning_rate: 5.0000e-04
# Epoch 8/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.3619 - loss: 1.2767 - val_accuracy: 0.2885 - val_loss: 1.4522 - learning_rate: 5.0000e-04
# Epoch 9/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.3580 - loss: 1.2388 - val_accuracy: 0.3254 - val_loss: 1.4039 - learning_rate: 5.0000e-04
# Epoch 10/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.3276 - loss: 1.2281 - val_accuracy: 0.3427 - val_loss: 1.3966 - learning_rate: 5.0000e-04
# Epoch 11/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.3846 - loss: 1.1840 - val_accuracy: 0.3536 - val_loss: 1.4323 - learning_rate: 5.0000e-04
# Epoch 12/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.4059 - loss: 1.1732 - val_accuracy: 0.3623 - val_loss: 1.4240 - learning_rate: 5.0000e-04
# Epoch 13/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.4292 - loss: 1.1317 - val_accuracy: 0.3796 - val_loss: 1.3692 - learning_rate: 5.0000e-04
# Epoch 14/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.4223 - loss: 1.1215 - val_accuracy: 0.4013 - val_loss: 1.3585 - learning_rate: 5.0000e-04
# Epoch 15/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.4537 - loss: 1.0875 - val_accuracy: 0.4187 - val_loss: 1.3294 - learning_rate: 5.0000e-04
# Epoch 16/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.4695 - loss: 1.0473 - val_accuracy: 0.4013 - val_loss: 1.3636 - learning_rate: 5.0000e-04
# Epoch 17/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.4803 - loss: 1.0340 - val_accuracy: 0.4295 - val_loss: 1.3621 - learning_rate: 5.0000e-04
# Epoch 18/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.4794 - loss: 1.0194 - val_accuracy: 0.3948 - val_loss: 1.3936 - learning_rate: 5.0000e-04
# Epoch 19/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.5107 - loss: 0.9702 - val_accuracy: 0.4100 - val_loss: 1.4047 - learning_rate: 5.0000e-04
# Epoch 20/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5043 - loss: 0.9392
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.5045 - loss: 0.9394 - val_accuracy: 0.4100 - val_loss: 1.3684 - learning_rate: 5.0000e-04
# Epoch 21/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.5308 - loss: 0.9146 - val_accuracy: 0.4273 - val_loss: 1.3771 - learning_rate: 2.5000e-04
# Epoch 22/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.5321 - loss: 0.8888 - val_accuracy: 0.4425 - val_loss: 1.4515 - learning_rate: 2.5000e-04
# Epoch 23/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.5389 - loss: 0.8704 - val_accuracy: 0.4295 - val_loss: 1.4339 - learning_rate: 2.5000e-04
# Epoch 24/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.5493 - loss: 0.8630 - val_accuracy: 0.4143 - val_loss: 1.3920 - learning_rate: 2.5000e-04
# Epoch 25/50
# 56/58 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5780 - loss: 0.8348
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.5775 - loss: 0.8351 - val_accuracy: 0.4273 - val_loss: 1.4016 - learning_rate: 2.5000e-04
# Epoch 25: early stopping
# Restoring model weights from the end of the best epoch: 15.
# Fold 1 - Validation Accuracy: 41.87%
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Fold 1 - Average ROC-AUC: 0.6604
#
# Training Fold 2/5
# Epoch 1/50
# c:\Users\karan\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 107ms/step - accuracy: 0.2615 - loss: 2.3941 - val_accuracy: 0.3102 - val_loss: 2.0347 - learning_rate: 0.0010
# Epoch 2/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 87ms/step - accuracy: 0.2816 - loss: 1.3621 - val_accuracy: 0.3189 - val_loss: 3.2145 - learning_rate: 0.0010
# Epoch 3/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 88ms/step - accuracy: 0.2980 - loss: 1.3375 - val_accuracy: 0.3275 - val_loss: 3.2992 - learning_rate: 0.0010
# Epoch 4/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.3393 - loss: 1.3100 - val_accuracy: 0.3688 - val_loss: 2.6723 - learning_rate: 0.0010
# Epoch 5/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.3618 - loss: 1.2873 - val_accuracy: 0.3774 - val_loss: 1.8810 - learning_rate: 0.0010
# Epoch 6/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - accuracy: 0.3891 - loss: 1.2650 - val_accuracy: 0.3753 - val_loss: 1.4562 - learning_rate: 0.0010
# Epoch 7/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 82ms/step - accuracy: 0.3861 - loss: 1.2351 - val_accuracy: 0.4273 - val_loss: 1.3379 - learning_rate: 0.0010
# Epoch 8/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 82ms/step - accuracy: 0.4200 - loss: 1.1883 - val_accuracy: 0.4121 - val_loss: 1.2998 - learning_rate: 0.0010
# Epoch 9/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 85ms/step - accuracy: 0.4458 - loss: 1.1293 - val_accuracy: 0.4143 - val_loss: 1.3707 - learning_rate: 0.0010
# Epoch 10/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 76ms/step - accuracy: 0.4735 - loss: 1.1182 - val_accuracy: 0.4208 - val_loss: 1.3063 - learning_rate: 0.0010
# Epoch 11/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.4699 - loss: 1.0803 - val_accuracy: 0.3970 - val_loss: 1.3292 - learning_rate: 0.0010
# Epoch 12/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.4803 - loss: 1.0630 - val_accuracy: 0.4252 - val_loss: 1.3086 - learning_rate: 0.0010
# Epoch 13/50
# 57/58 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.4972 - loss: 1.0102
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.4969 - loss: 1.0110 - val_accuracy: 0.4143 - val_loss: 1.3134 - learning_rate: 0.0010
# Epoch 14/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 81ms/step - accuracy: 0.5207 - loss: 0.9912 - val_accuracy: 0.3905 - val_loss: 1.3459 - learning_rate: 5.0000e-04
# Epoch 15/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.5197 - loss: 0.9392 - val_accuracy: 0.4056 - val_loss: 1.3653 - learning_rate: 5.0000e-04
# Epoch 16/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.5457 - loss: 0.9005 - val_accuracy: 0.3883 - val_loss: 1.3801 - learning_rate: 5.0000e-04
# Epoch 17/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 86ms/step - accuracy: 0.5690 - loss: 0.8601 - val_accuracy: 0.4035 - val_loss: 1.3841 - learning_rate: 5.0000e-04
# Epoch 18/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5567 - loss: 0.8675
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.5567 - loss: 0.8673 - val_accuracy: 0.3905 - val_loss: 1.3588 - learning_rate: 5.0000e-04
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Fold 2 - Validation Accuracy: 41.21%
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step
# Fold 2 - Average ROC-AUC: 0.6706
#
# Training Fold 3/5
# c:\Users\karan\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 26s 107ms/step - accuracy: 0.2618 - loss: 2.2764 - val_accuracy: 0.2777 - val_loss: 2.0129 - learning_rate: 0.0010
# Epoch 2/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.2508 - loss: 1.3781 - val_accuracy: 0.2603 - val_loss: 3.9976 - learning_rate: 0.0010
# Epoch 3/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - accuracy: 0.2806 - loss: 1.3779 - val_accuracy: 0.2473 - val_loss: 4.3760 - learning_rate: 0.0010
# Epoch 4/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 76ms/step - accuracy: 0.2529 - loss: 1.3956 - val_accuracy: 0.2625 - val_loss: 3.6106 - learning_rate: 0.0010
# Epoch 5/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.2821 - loss: 1.3576 - val_accuracy: 0.2625 - val_loss: 2.4709 - learning_rate: 0.0010
# Epoch 6/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - accuracy: 0.2965 - loss: 1.3473 - val_accuracy: 0.2863 - val_loss: 1.6996 - learning_rate: 0.0010
# Epoch 7/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.3011 - loss: 1.3250 - val_accuracy: 0.2603 - val_loss: 1.5104 - learning_rate: 0.0010
# Epoch 8/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 86ms/step - accuracy: 0.3079 - loss: 1.3477 - val_accuracy: 0.2842 - val_loss: 1.3853 - learning_rate: 0.0010
# Epoch 9/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 89ms/step - accuracy: 0.2967 - loss: 1.3261 - val_accuracy: 0.3037 - val_loss: 1.3811 - learning_rate: 0.0010
# Epoch 10/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 89ms/step - accuracy: 0.3248 - loss: 1.3536 - val_accuracy: 0.2928 - val_loss: 1.3872 - learning_rate: 0.0010
# Epoch 11/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 86ms/step - accuracy: 0.3315 - loss: 1.3165 - val_accuracy: 0.2777 - val_loss: 1.3741 - learning_rate: 0.0010
# Epoch 12/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 88ms/step - accuracy: 0.3541 - loss: 1.2637 - val_accuracy: 0.3059 - val_loss: 1.3776 - learning_rate: 0.0010
# Epoch 13/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 92ms/step - accuracy: 0.3411 - loss: 1.2680 - val_accuracy: 0.2928 - val_loss: 1.4504 - learning_rate: 0.0010
# Epoch 14/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - accuracy: 0.3660 - loss: 1.2720 - val_accuracy: 0.2993 - val_loss: 1.3533 - learning_rate: 0.0010
# Epoch 15/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 87ms/step - accuracy: 0.3557 - loss: 1.2500 - val_accuracy: 0.2842 - val_loss: 1.3828 - learning_rate: 0.0010
# Epoch 16/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 91ms/step - accuracy: 0.3684 - loss: 1.2273 - val_accuracy: 0.3015 - val_loss: 1.3875 - learning_rate: 0.0010
# Epoch 17/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - accuracy: 0.3631 - loss: 1.2148 - val_accuracy: 0.3037 - val_loss: 1.4069 - learning_rate: 0.0010
# Epoch 18/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 102ms/step - accuracy: 0.3842 - loss: 1.2174 - val_accuracy: 0.3232 - val_loss: 1.4279 - learning_rate: 0.0010
# Epoch 19/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.3930 - loss: 1.2191
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 7s 108ms/step - accuracy: 0.3927 - loss: 1.2191 - val_accuracy: 0.3059 - val_loss: 1.3922 - learning_rate: 0.0010
# Epoch 20/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - accuracy: 0.4023 - loss: 1.1571 - val_accuracy: 0.3059 - val_loss: 1.3853 - learning_rate: 5.0000e-04
# Epoch 21/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - accuracy: 0.3953 - loss: 1.1493 - val_accuracy: 0.3319 - val_loss: 1.4031 - learning_rate: 5.0000e-04
# Epoch 22/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 103ms/step - accuracy: 0.4181 - loss: 1.1451 - val_accuracy: 0.3362 - val_loss: 1.4085 - learning_rate: 5.0000e-04
# Epoch 23/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - accuracy: 0.4152 - loss: 1.1161 - val_accuracy: 0.3145 - val_loss: 1.4341 - learning_rate: 5.0000e-04
# Epoch 24/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.4484 - loss: 1.1098
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.4480 - loss: 1.1101 - val_accuracy: 0.2972 - val_loss: 1.4360 - learning_rate: 5.0000e-04
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 14.
# Fold 3 - Validation Accuracy: 29.93%
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step
# Fold 3 - Average ROC-AUC: 0.5660
#
# Training Fold 4/5
# c:\Users\karan\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 14s 69ms/step - accuracy: 0.2694 - loss: 2.5501 - val_accuracy: 0.2863 - val_loss: 1.8540 - learning_rate: 0.0010
# Epoch 2/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.2774 - loss: 1.3755 - val_accuracy: 0.2820 - val_loss: 3.8914 - learning_rate: 0.0010
# Epoch 3/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.2855 - loss: 1.3647 - val_accuracy: 0.3124 - val_loss: 3.5129 - learning_rate: 0.0010
# Epoch 4/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.3067 - loss: 1.3551 - val_accuracy: 0.2907 - val_loss: 3.1164 - learning_rate: 0.0010
# Epoch 5/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.3226 - loss: 1.3115 - val_accuracy: 0.3449 - val_loss: 1.9592 - learning_rate: 0.0010
# Epoch 6/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.3511 - loss: 1.2934 - val_accuracy: 0.3319 - val_loss: 1.5821 - learning_rate: 0.0010
# Epoch 7/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.3486 - loss: 1.2641 - val_accuracy: 0.3644 - val_loss: 1.3958 - learning_rate: 0.0010
# Epoch 8/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.3829 - loss: 1.2443 - val_accuracy: 0.3406 - val_loss: 1.3940 - learning_rate: 0.0010
# Epoch 9/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.3795 - loss: 1.2102 - val_accuracy: 0.3666 - val_loss: 1.3632 - learning_rate: 0.0010
# Epoch 10/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.4124 - loss: 1.1978 - val_accuracy: 0.3384 - val_loss: 1.3450 - learning_rate: 0.0010
# Epoch 11/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.3690 - loss: 1.2148 - val_accuracy: 0.3644 - val_loss: 1.3226 - learning_rate: 0.0010
# Epoch 12/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.4075 - loss: 1.1867 - val_accuracy: 0.3471 - val_loss: 1.3205 - learning_rate: 0.0010
# Epoch 13/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.4258 - loss: 1.1539 - val_accuracy: 0.3492 - val_loss: 1.3419 - learning_rate: 0.0010
# Epoch 14/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.4331 - loss: 1.1374 - val_accuracy: 0.3623 - val_loss: 1.3235 - learning_rate: 0.0010
# Epoch 15/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.4440 - loss: 1.1351 - val_accuracy: 0.3514 - val_loss: 1.3331 - learning_rate: 0.0010
# Epoch 16/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - accuracy: 0.4692 - loss: 1.0771 - val_accuracy: 0.3384 - val_loss: 1.3373 - learning_rate: 0.0010
# Epoch 17/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.4567 - loss: 1.0782
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 95ms/step - accuracy: 0.4567 - loss: 1.0782 - val_accuracy: 0.3579 - val_loss: 1.4134 - learning_rate: 0.0010
# Epoch 18/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 88ms/step - accuracy: 0.4644 - loss: 1.0586 - val_accuracy: 0.3774 - val_loss: 1.3860 - learning_rate: 5.0000e-04
# Epoch 19/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 88ms/step - accuracy: 0.4775 - loss: 1.0533 - val_accuracy: 0.3666 - val_loss: 1.3375 - learning_rate: 5.0000e-04
# Epoch 20/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - accuracy: 0.5080 - loss: 0.9704 - val_accuracy: 0.3644 - val_loss: 1.3143 - learning_rate: 5.0000e-04
# Epoch 21/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - accuracy: 0.4867 - loss: 0.9970 - val_accuracy: 0.3644 - val_loss: 1.3677 - learning_rate: 5.0000e-04
# Epoch 22/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 90ms/step - accuracy: 0.5023 - loss: 1.0107 - val_accuracy: 0.3644 - val_loss: 1.3607 - learning_rate: 5.0000e-04
# Epoch 23/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - accuracy: 0.5074 - loss: 0.9493 - val_accuracy: 0.3688 - val_loss: 1.3496 - learning_rate: 5.0000e-04
# Epoch 24/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - accuracy: 0.5169 - loss: 0.9718 - val_accuracy: 0.3818 - val_loss: 1.3213 - learning_rate: 5.0000e-04
# Epoch 25/50
# 57/58 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.5366 - loss: 0.9334
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - accuracy: 0.5360 - loss: 0.9341 - val_accuracy: 0.3905 - val_loss: 1.3270 - learning_rate: 5.0000e-04
# Epoch 26/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 90ms/step - accuracy: 0.5399 - loss: 0.9290 - val_accuracy: 0.3883 - val_loss: 1.3707 - learning_rate: 2.5000e-04
# Epoch 27/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 105ms/step - accuracy: 0.5481 - loss: 0.9170 - val_accuracy: 0.3796 - val_loss: 1.3502 - learning_rate: 2.5000e-04
# Epoch 28/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 101ms/step - accuracy: 0.5399 - loss: 0.8820 - val_accuracy: 0.3774 - val_loss: 1.3557 - learning_rate: 2.5000e-04
# Epoch 29/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 102ms/step - accuracy: 0.5352 - loss: 0.9081 - val_accuracy: 0.3883 - val_loss: 1.3571 - learning_rate: 2.5000e-04
# Epoch 30/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.5513 - loss: 0.9030
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 108ms/step - accuracy: 0.5513 - loss: 0.9030 - val_accuracy: 0.3905 - val_loss: 1.3837 - learning_rate: 2.5000e-04
# Epoch 30: early stopping
# Restoring model weights from the end of the best epoch: 20.
# Fold 4 - Validation Accuracy: 36.44%
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step
# Fold 4 - Average ROC-AUC: 0.6449
#
# Training Fold 5/5
# c:\Users\karan\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 38s 139ms/step - accuracy: 0.2767 - loss: 2.1037 - val_accuracy: 0.2870 - val_loss: 1.5334 - learning_rate: 0.0010
# Epoch 2/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 87ms/step - accuracy: 0.2593 - loss: 1.3812 - val_accuracy: 0.2848 - val_loss: 2.3211 - learning_rate: 0.0010
# Epoch 3/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 86ms/step - accuracy: 0.2731 - loss: 1.3701 - val_accuracy: 0.2587 - val_loss: 2.5087 - learning_rate: 0.0010
# Epoch 4/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 82ms/step - accuracy: 0.2836 - loss: 1.3633 - val_accuracy: 0.2826 - val_loss: 2.2343 - learning_rate: 0.0010
# Epoch 5/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - accuracy: 0.2772 - loss: 1.3452 - val_accuracy: 0.2870 - val_loss: 1.8194 - learning_rate: 0.0010
# Epoch 6/50
# 57/58 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.3042 - loss: 1.3393
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.3036 - loss: 1.3394 - val_accuracy: 0.3065 - val_loss: 1.5701 - learning_rate: 0.0010
# Epoch 7/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.3282 - loss: 1.2876 - val_accuracy: 0.3326 - val_loss: 1.4057 - learning_rate: 5.0000e-04
# Epoch 8/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.3210 - loss: 1.2800 - val_accuracy: 0.3413 - val_loss: 1.3501 - learning_rate: 5.0000e-04
# Epoch 9/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 82ms/step - accuracy: 0.3382 - loss: 1.2314 - val_accuracy: 0.3457 - val_loss: 1.3437 - learning_rate: 5.0000e-04
# Epoch 10/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.3804 - loss: 1.2207 - val_accuracy: 0.3435 - val_loss: 1.3006 - learning_rate: 5.0000e-04
# Epoch 11/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - accuracy: 0.3840 - loss: 1.1914 - val_accuracy: 0.3500 - val_loss: 1.3305 - learning_rate: 5.0000e-04
# Epoch 12/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 86ms/step - accuracy: 0.3908 - loss: 1.1835 - val_accuracy: 0.3783 - val_loss: 1.3371 - learning_rate: 5.0000e-04
# Epoch 13/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.4165 - loss: 1.1570 - val_accuracy: 0.3652 - val_loss: 1.3300 - learning_rate: 5.0000e-04
# Epoch 14/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 95ms/step - accuracy: 0.4380 - loss: 1.1311 - val_accuracy: 0.3609 - val_loss: 1.3483 - learning_rate: 5.0000e-04
# Epoch 15/50
# 57/58 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.4542 - loss: 1.0949
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - accuracy: 0.4540 - loss: 1.0951 - val_accuracy: 0.3739 - val_loss: 1.3343 - learning_rate: 5.0000e-04
# Epoch 16/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 86ms/step - accuracy: 0.4675 - loss: 1.0433 - val_accuracy: 0.4130 - val_loss: 1.3275 - learning_rate: 2.5000e-04
# Epoch 17/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - accuracy: 0.4502 - loss: 1.0513 - val_accuracy: 0.3739 - val_loss: 1.3375 - learning_rate: 2.5000e-04
# Epoch 18/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - accuracy: 0.4837 - loss: 0.9802 - val_accuracy: 0.3957 - val_loss: 1.3283 - learning_rate: 2.5000e-04
# Epoch 19/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - accuracy: 0.5079 - loss: 0.9475 - val_accuracy: 0.4043 - val_loss: 1.3814 - learning_rate: 2.5000e-04
# Epoch 20/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.4961 - loss: 0.9629
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 7s 107ms/step - accuracy: 0.4962 - loss: 0.9627 - val_accuracy: 0.3891 - val_loss: 1.3550 - learning_rate: 2.5000e-04
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
# Fold 5 - Validation Accuracy: 34.35%
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step
# Fold 5 - Average ROC-AUC: 0.6391
#
# Cross-Validation Results:
# Average Accuracy: 36.76%
# Standard Deviation of Accuracy: 4.44%
# Average Loss: 1.3195
# Standard Deviation of Loss: 0.0200
# Average ROC-AUC: 0.6362
# Standard Deviation of ROC-AUC: 0.0368
