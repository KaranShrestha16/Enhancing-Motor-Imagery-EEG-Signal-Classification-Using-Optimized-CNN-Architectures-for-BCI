# %%
import mne
import numpy as np
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc, confusion_matrix, classification_report
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, DepthwiseConv2D, SeparableConv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
import matplotlib.pyplot as plt

# ---------------- Data Loading and Preprocessing ----------------

base_path = r'C:\\Users\\karan\\Downloads\\EEG Data\\Data'
subjects = [f'A0{i}' for i in range(1, 10) if i != 4]
event_ids = [7, 8, 9, 10]  # Event IDs for motor imagery tasks

all_features, all_labels = [], []

for subject in subjects:
    file_path = f'{base_path}\\{subject}T.gdf'
    print(f"Processing {subject}...")

    raw = mne.io.read_raw_gdf(file_path, preload=True)
    raw.drop_channels(['EOG-left', 'EOG-central', 'EOG-right'])
    raw.set_eeg_reference()
    raw.filter(8., 30., fir_design='firwin', verbose=False)

    ica = mne.preprocessing.ICA(n_components=15, random_state=97, max_iter=800)
    ica.fit(raw)
    raw = ica.apply(raw)

    events, _ = mne.events_from_annotations(raw)
    epochs = mne.Epochs(raw, events, event_id=event_ids, tmin=0.5, tmax=4.0, baseline=(0.5, 1.0), preload=True)

    all_features.append(epochs.get_data())
    all_labels.append(epochs.events[:, -1])

features = np.concatenate(all_features, axis=0)
labels = np.concatenate(all_labels, axis=0)

# ---------------- Data Preparation ----------------

binary_labels = np.where(labels == 8, 1, 0)  # Event ID for Right Hand is 8
right_features = features[binary_labels == 1]
non_right_features = features[binary_labels == 0]

n_right = len(right_features)
n_non_right = len(non_right_features)
oversampled_right_features = np.tile(right_features, (n_non_right // n_right, 1, 1))
remainder = n_non_right % n_right
if remainder > 0:
    oversampled_right_features = np.concatenate([oversampled_right_features, right_features[:remainder]], axis=0)

balanced_features = np.concatenate([oversampled_right_features, non_right_features], axis=0)
balanced_labels = np.concatenate([np.ones(len(oversampled_right_features)), np.zeros(n_non_right)], axis=0)

balanced_features = (balanced_features - np.mean(balanced_features, axis=0)) / np.std(balanced_features, axis=0)

noise_factor = 0.05
augmented_features = balanced_features + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=balanced_features.shape)
augmented_features = np.clip(augmented_features, -1.0, 1.0)

final_features = np.concatenate((balanced_features, augmented_features))
final_labels = np.concatenate((balanced_labels, balanced_labels))
final_features, final_labels = shuffle(final_features, final_labels, random_state=42)

X_train, X_test, y_train, y_test = train_test_split(final_features, final_labels, test_size=0.15, random_state=42)
X_train = X_train[..., np.newaxis]
X_test = X_test[..., np.newaxis]

# ---------------- Build the Model ----------------

model = Sequential()
model.add(Conv2D(8, kernel_size=(1, 64), padding='same', input_shape=(22, X_train.shape[2], 1),
                 activation='relu', kernel_regularizer=l2(0.01)))
model.add(BatchNormalization())
model.add(DepthwiseConv2D(kernel_size=(22, 1), depth_multiplier=2, use_bias=False, activation='relu',
                          depthwise_regularizer=l2(0.01)))
model.add(BatchNormalization())
model.add(Dropout(0.3))
model.add(SeparableConv2D(16, kernel_size=(1, 16), use_bias=False, padding='same', activation='relu',
                          depthwise_regularizer=l2(0.01)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(1, 4)))
model.add(Dropout(0.4))
model.add(Flatten())
model.add(Dense(64, activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# ---------------- Train the Model ----------------

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-5, verbose=1)
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)

history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.15,
                    callbacks=[reduce_lr, early_stopping], verbose=1)

# ---------------- Evaluate the Model ----------------

test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")

y_pred_probs = model.predict(X_test)
y_pred = (y_pred_probs > 0.5).astype(int)

conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", conf_matrix)
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# ---------------- Plot Confusion Matrix ----------------

def plot_confusion_matrix(cm, class_names, title="Confusion Matrix"):
    plt.figure(figsize=(6, 6))
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(class_names))
    plt.xticks(tick_marks, class_names, rotation=45)
    plt.yticks(tick_marks, class_names)

    fmt = 'd'
    thresh = cm.max() / 2
    for i, j in np.ndindex(cm.shape):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.tight_layout()
    plt.show()

plot_confusion_matrix(
    conf_matrix,
    class_names=['Non-Right', 'Right'],
    title="Enhanced EEGNet: Right vs Non-Right Model - Confusion Matrix"
)

# ---------------- Plot Training and Validation Trends ----------------

# Training and Validation Accuracy
plt.figure()
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Enhanced EEGNet: Right vs Non-Right Model - Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()
plt.show()

# Training and Validation Loss
plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Enhanced EEGNet: Right vs Non-Right Model - Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()

# ---------------- Plot ROC Curve ----------------

fpr, tpr, _ = roc_curve(y_test, y_pred_probs)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
plt.title('Enhanced EEGNet: Right vs Non-Right Model - ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.grid()
plt.show()
# Out:
# Processing A01...
# Extracting EDF parameters from C:\Users\karan\Downloads\EEG Data\Data\A01T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG, EOG-left, EOG-central, EOG-right
# Creating raw.info structure...
# c:\Users\karan\anaconda3\Lib\contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Reading 0 ... 672527  =      0.000 ...  2690.108 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Fitting ICA to data using 22 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 18.4s.
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 0 ICA components
#     Projecting back using 22 PCA components
# Used Annotations descriptions: ['1023', '1072', '276', '277', '32766', '768', '769', '770', '771', '772']
# Not setting metadata
# 288 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 288 events and 876 original time points ...
# 0 bad epochs dropped
# Processing A02...
# Extracting EDF parameters from C:\Users\karan\Downloads\EEG Data\Data\A02T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG, EOG-left, EOG-central, EOG-right
# Creating raw.info structure...
# Reading 0 ... 677168  =      0.000 ...  2708.672 secs...
# c:\Users\karan\anaconda3\Lib\contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Fitting ICA to data using 22 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 22.0s.
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 0 ICA components
#     Projecting back using 22 PCA components
# Used Annotations descriptions: ['1023', '1072', '276', '277', '32766', '768', '769', '770', '771', '772']
# Not setting metadata
# 288 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 288 events and 876 original time points ...
# 0 bad epochs dropped
# Processing A03...
# Extracting EDF parameters from C:\Users\karan\Downloads\EEG Data\Data\A03T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG, EOG-left, EOG-central, EOG-right
# Creating raw.info structure...
# Reading 0 ... 660529  =      0.000 ...  2642.116 secs...
# c:\Users\karan\anaconda3\Lib\contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Fitting ICA to data using 22 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 26.4s.
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 0 ICA components
#     Projecting back using 22 PCA components
# Used Annotations descriptions: ['1023', '1072', '276', '277', '32766', '768', '769', '770', '771', '772']
# Not setting metadata
# 288 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 288 events and 876 original time points ...
# 0 bad epochs dropped
# Processing A05...
# Extracting EDF parameters from C:\Users\karan\Downloads\EEG Data\Data\A05T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG, EOG-left, EOG-central, EOG-right
# Creating raw.info structure...
# Reading 0 ... 686119  =      0.000 ...  2744.476 secs...
# c:\Users\karan\anaconda3\Lib\contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Fitting ICA to data using 22 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 21.0s.
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 0 ICA components
#     Projecting back using 22 PCA components
# Used Annotations descriptions: ['1023', '1072', '276', '277', '32766', '768', '769', '770', '771', '772']
# Not setting metadata
# 288 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 288 events and 876 original time points ...
# 0 bad epochs dropped
# Processing A06...
# Extracting EDF parameters from C:\Users\karan\Downloads\EEG Data\Data\A06T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG, EOG-left, EOG-central, EOG-right
# Creating raw.info structure...
# Reading 0 ... 678979  =      0.000 ...  2715.916 secs...
# c:\Users\karan\anaconda3\Lib\contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Fitting ICA to data using 22 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 24.8s.
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 0 ICA components
#     Projecting back using 22 PCA components
# Used Annotations descriptions: ['1023', '1072', '276', '277', '32766', '768', '769', '770', '771', '772']
# Not setting metadata
# 288 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 288 events and 876 original time points ...
# 0 bad epochs dropped
# Processing A07...
# Extracting EDF parameters from C:\Users\karan\Downloads\EEG Data\Data\A07T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG, EOG-left, EOG-central, EOG-right
# Creating raw.info structure...
# Reading 0 ... 681070  =      0.000 ...  2724.280 secs...
# c:\Users\karan\anaconda3\Lib\contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Fitting ICA to data using 22 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 16.4s.
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 0 ICA components
#     Projecting back using 22 PCA components
# Used Annotations descriptions: ['1023', '1072', '276', '277', '32766', '768', '769', '770', '771', '772']
# Not setting metadata
# 288 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 288 events and 876 original time points ...
# 0 bad epochs dropped
# Processing A08...
# Extracting EDF parameters from C:\Users\karan\Downloads\EEG Data\Data\A08T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG, EOG-left, EOG-central, EOG-right
# Creating raw.info structure...
# Reading 0 ... 675269  =      0.000 ...  2701.076 secs...
# c:\Users\karan\anaconda3\Lib\contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Fitting ICA to data using 22 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 22.5s.
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 0 ICA components
#     Projecting back using 22 PCA components
# Used Annotations descriptions: ['1023', '1072', '276', '277', '32766', '768', '769', '770', '771', '772']
# Not setting metadata
# 288 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 288 events and 876 original time points ...
# 0 bad epochs dropped
# Processing A09...
# Extracting EDF parameters from C:\Users\karan\Downloads\EEG Data\Data\A09T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG, EOG-left, EOG-central, EOG-right
# Creating raw.info structure...
# Reading 0 ... 673327  =      0.000 ...  2693.308 secs...
# c:\Users\karan\anaconda3\Lib\contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Fitting ICA to data using 22 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 26.0s.
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 0 ICA components
#     Projecting back using 22 PCA components
# Used Annotations descriptions: ['1023', '1072', '276', '277', '32766', '768', '769', '770', '771', '772']
# Not setting metadata
# 288 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 288 events and 876 original time points ...
# 0 bad epochs dropped
# c:\Users\karan\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 32s 141ms/step - accuracy: 0.5507 - loss: 2.0666 - val_accuracy: 0.5136 - val_loss: 1.4410 - learning_rate: 0.0010
# Epoch 2/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 124ms/step - accuracy: 0.6144 - loss: 1.2775 - val_accuracy: 0.6780 - val_loss: 1.0704 - learning_rate: 0.0010
# Epoch 3/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 19s 123ms/step - accuracy: 0.7282 - loss: 0.9892 - val_accuracy: 0.7302 - val_loss: 0.9735 - learning_rate: 0.0010
# Epoch 4/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 18s 115ms/step - accuracy: 0.7791 - loss: 0.9006 - val_accuracy: 0.8231 - val_loss: 0.8605 - learning_rate: 0.0010
# Epoch 5/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 18s 116ms/step - accuracy: 0.8313 - loss: 0.8268 - val_accuracy: 0.8243 - val_loss: 0.8356 - learning_rate: 0.0010
# Epoch 6/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 18s 115ms/step - accuracy: 0.8586 - loss: 0.8248 - val_accuracy: 0.8435 - val_loss: 0.8629 - learning_rate: 0.0010
# Epoch 7/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 18s 114ms/step - accuracy: 0.8670 - loss: 0.8071 - val_accuracy: 0.8764 - val_loss: 0.7792 - learning_rate: 0.0010
# Epoch 8/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 19s 118ms/step - accuracy: 0.8855 - loss: 0.7644 - val_accuracy: 0.9036 - val_loss: 0.7334 - learning_rate: 0.0010
# Epoch 9/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 19s 118ms/step - accuracy: 0.9014 - loss: 0.7298 - val_accuracy: 0.8991 - val_loss: 0.7504 - learning_rate: 0.0010
# Epoch 10/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 17s 105ms/step - accuracy: 0.8832 - loss: 0.7854 - val_accuracy: 0.9150 - val_loss: 0.7447 - learning_rate: 0.0010
# Epoch 11/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 8s 52ms/step - accuracy: 0.8828 - loss: 0.8576 - val_accuracy: 0.9104 - val_loss: 0.7896 - learning_rate: 0.0010
# Epoch 12/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 16s 105ms/step - accuracy: 0.9083 - loss: 0.7676 - val_accuracy: 0.9161 - val_loss: 0.7432 - learning_rate: 0.0010
# Epoch 13/50
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.8962 - loss: 0.7889
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 18s 116ms/step - accuracy: 0.8961 - loss: 0.7890 - val_accuracy: 0.9036 - val_loss: 0.7547 - learning_rate: 0.0010
# Epoch 14/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 129ms/step - accuracy: 0.9091 - loss: 0.7508 - val_accuracy: 0.9342 - val_loss: 0.6451 - learning_rate: 5.0000e-04
# Epoch 15/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 125ms/step - accuracy: 0.9319 - loss: 0.6325 - val_accuracy: 0.9592 - val_loss: 0.5516 - learning_rate: 5.0000e-04
# Epoch 16/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 126ms/step - accuracy: 0.9386 - loss: 0.5654 - val_accuracy: 0.9286 - val_loss: 0.5452 - learning_rate: 5.0000e-04
# Epoch 17/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 128ms/step - accuracy: 0.9429 - loss: 0.5240 - val_accuracy: 0.9478 - val_loss: 0.4940 - learning_rate: 5.0000e-04
# Epoch 18/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 130ms/step - accuracy: 0.9402 - loss: 0.5157 - val_accuracy: 0.9490 - val_loss: 0.4922 - learning_rate: 5.0000e-04
# Epoch 19/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 128ms/step - accuracy: 0.9520 - loss: 0.4819 - val_accuracy: 0.9535 - val_loss: 0.4786 - learning_rate: 5.0000e-04
# Epoch 20/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 133ms/step - accuracy: 0.9463 - loss: 0.4673 - val_accuracy: 0.9580 - val_loss: 0.4484 - learning_rate: 5.0000e-04
# Epoch 21/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 126ms/step - accuracy: 0.9187 - loss: 0.5557 - val_accuracy: 0.9524 - val_loss: 0.5266 - learning_rate: 5.0000e-04
# Epoch 22/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 129ms/step - accuracy: 0.9149 - loss: 0.6062 - val_accuracy: 0.9286 - val_loss: 0.5704 - learning_rate: 5.0000e-04
# Epoch 23/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 130ms/step - accuracy: 0.9507 - loss: 0.5259 - val_accuracy: 0.9558 - val_loss: 0.5066 - learning_rate: 5.0000e-04
# Epoch 24/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 127ms/step - accuracy: 0.9576 - loss: 0.4837 - val_accuracy: 0.9512 - val_loss: 0.4989 - learning_rate: 5.0000e-04
# Epoch 25/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 133ms/step - accuracy: 0.9470 - loss: 0.4858 - val_accuracy: 0.9660 - val_loss: 0.4468 - learning_rate: 5.0000e-04
# Epoch 26/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 130ms/step - accuracy: 0.9516 - loss: 0.4615 - val_accuracy: 0.9456 - val_loss: 0.4726 - learning_rate: 5.0000e-04
# Epoch 27/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 128ms/step - accuracy: 0.9424 - loss: 0.4728 - val_accuracy: 0.9546 - val_loss: 0.4496 - learning_rate: 5.0000e-04
# Epoch 28/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 129ms/step - accuracy: 0.9557 - loss: 0.4374 - val_accuracy: 0.9694 - val_loss: 0.4160 - learning_rate: 5.0000e-04
# Epoch 29/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 125ms/step - accuracy: 0.9604 - loss: 0.4239 - val_accuracy: 0.9649 - val_loss: 0.4188 - learning_rate: 5.0000e-04
# Epoch 30/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 125ms/step - accuracy: 0.9506 - loss: 0.4391 - val_accuracy: 0.9580 - val_loss: 0.4187 - learning_rate: 5.0000e-04
# Epoch 31/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 19s 123ms/step - accuracy: 0.9529 - loss: 0.4299 - val_accuracy: 0.9603 - val_loss: 0.4180 - learning_rate: 5.0000e-04
# Epoch 32/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 124ms/step - accuracy: 0.9415 - loss: 0.4870 - val_accuracy: 0.9592 - val_loss: 0.4766 - learning_rate: 5.0000e-04
# Epoch 33/50
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9510 - loss: 0.4689
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 19s 121ms/step - accuracy: 0.9510 - loss: 0.4688 - val_accuracy: 0.9660 - val_loss: 0.4521 - learning_rate: 5.0000e-04
# Epoch 34/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 125ms/step - accuracy: 0.9562 - loss: 0.4372 - val_accuracy: 0.9615 - val_loss: 0.4317 - learning_rate: 2.5000e-04
# Epoch 35/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 126ms/step - accuracy: 0.9647 - loss: 0.3976 - val_accuracy: 0.9524 - val_loss: 0.4249 - learning_rate: 2.5000e-04
# Epoch 36/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 126ms/step - accuracy: 0.9690 - loss: 0.3673 - val_accuracy: 0.9626 - val_loss: 0.3789 - learning_rate: 2.5000e-04
# Epoch 37/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 127ms/step - accuracy: 0.9730 - loss: 0.3474 - val_accuracy: 0.9717 - val_loss: 0.3538 - learning_rate: 2.5000e-04
# Epoch 38/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 124ms/step - accuracy: 0.9634 - loss: 0.3487 - val_accuracy: 0.9717 - val_loss: 0.3310 - learning_rate: 2.5000e-04
# Epoch 39/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 19s 123ms/step - accuracy: 0.9765 - loss: 0.3220 - val_accuracy: 0.9694 - val_loss: 0.3357 - learning_rate: 2.5000e-04
# Epoch 40/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 125ms/step - accuracy: 0.9757 - loss: 0.3041 - val_accuracy: 0.9660 - val_loss: 0.3265 - learning_rate: 2.5000e-04
# Epoch 41/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 125ms/step - accuracy: 0.9679 - loss: 0.3186 - val_accuracy: 0.9592 - val_loss: 0.3412 - learning_rate: 2.5000e-04
# Epoch 42/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 125ms/step - accuracy: 0.9744 - loss: 0.3009 - val_accuracy: 0.9683 - val_loss: 0.3252 - learning_rate: 2.5000e-04
# Epoch 43/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 124ms/step - accuracy: 0.9723 - loss: 0.2943 - val_accuracy: 0.9671 - val_loss: 0.3055 - learning_rate: 2.5000e-04
# Epoch 44/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 127ms/step - accuracy: 0.9764 - loss: 0.2870 - val_accuracy: 0.9626 - val_loss: 0.3210 - learning_rate: 2.5000e-04
# Epoch 45/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 127ms/step - accuracy: 0.9708 - loss: 0.2985 - val_accuracy: 0.9717 - val_loss: 0.3081 - learning_rate: 2.5000e-04
# Epoch 46/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 130ms/step - accuracy: 0.9743 - loss: 0.2916 - val_accuracy: 0.9546 - val_loss: 0.3347 - learning_rate: 2.5000e-04
# Epoch 47/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 135ms/step - accuracy: 0.9783 - loss: 0.2773 - val_accuracy: 0.9637 - val_loss: 0.3053 - learning_rate: 2.5000e-04
# Epoch 48/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 133ms/step - accuracy: 0.9780 - loss: 0.2713 - val_accuracy: 0.9739 - val_loss: 0.2842 - learning_rate: 2.5000e-04
# Epoch 49/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 15s 95ms/step - accuracy: 0.9706 - loss: 0.2689 - val_accuracy: 0.9660 - val_loss: 0.2886 - learning_rate: 2.5000e-04
# Epoch 50/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 16s 102ms/step - accuracy: 0.9728 - loss: 0.2735 - val_accuracy: 0.9717 - val_loss: 0.2922 - learning_rate: 2.5000e-04
# Restoring model weights from the end of the best epoch: 48.
# Test Accuracy: 97.11%
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step
# Confusion Matrix:
#  [[494  28]
#  [  2 513]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      0.95      0.97       522
#          1.0       0.95      1.00      0.97       515
#
#     accuracy                           0.97      1037
#    macro avg       0.97      0.97      0.97      1037
# weighted avg       0.97      0.97      0.97      1037

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, roc_auc_score, classification_report, confusion_matrix
import numpy as np

# Initialize Stratified K-Fold
n_splits = 5
skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

# Arrays to store performance metrics for each fold
accuracies = []
roc_aucs = []
confusion_matrices = []

fold = 1
for train_index, val_index in skf.split(final_features, final_labels):
    print(f"\nTraining Fold {fold}/{n_splits}...")
    
    # Split the data into training and validation sets
    X_train, X_val = final_features[train_index], final_features[val_index]
    y_train, y_val = final_labels[train_index], final_labels[val_index]
    
    # Reshape data for CNN input
    X_train = X_train[..., np.newaxis]
    X_val = X_val[..., np.newaxis]
    
    # Build the EEGNet model
    model = Sequential()
    model.add(Conv2D(8, kernel_size=(1, 64), padding='same', input_shape=(22, X_train.shape[2], 1),
                     activation='relu', kernel_regularizer=l2(0.01)))
    model.add(BatchNormalization())
    model.add(DepthwiseConv2D(kernel_size=(22, 1), depth_multiplier=2, use_bias=False, activation='relu',
                              depthwise_regularizer=l2(0.01)))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(SeparableConv2D(16, kernel_size=(1, 16), use_bias=False, padding='same', activation='relu',
                              depthwise_regularizer=l2(0.01)))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(1, 4)))
    model.add(Dropout(0.4))
    model.add(Flatten())
    model.add(Dense(64, activation='relu', kernel_regularizer=l2(0.01)))
    model.add(Dropout(0.5))
    model.add(Dense(1, activation='sigmoid'))  # Binary classification
    
    # Compile the model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                  loss='binary_crossentropy', metrics=['accuracy'])
    
    # Callbacks
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-5, verbose=1)
    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)
    
    # Train the model
    model.fit(
        X_train, y_train,
        epochs=50,
        batch_size=32,
        validation_data=(X_val, y_val),
        callbacks=[reduce_lr, early_stopping],
        verbose=1
    )
    
    # Evaluate the model on the validation set
    y_val_pred_probs = model.predict(X_val)
    y_val_pred = (y_val_pred_probs > 0.5).astype(int)
    
    # Calculate metrics
    accuracy = accuracy_score(y_val, y_val_pred)
    roc_auc = roc_auc_score(y_val, y_val_pred_probs)
    confusion = confusion_matrix(y_val, y_val_pred)
    
    # Store metrics
    accuracies.append(accuracy)
    roc_aucs.append(roc_auc)
    confusion_matrices.append(confusion)
    
    # Print fold-specific results
    print(f"Fold {fold} Accuracy: {accuracy:.4f}, ROC-AUC: {roc_auc:.4f}")
    print("Confusion Matrix:")
    print(confusion)
    
    fold += 1

# Aggregate metrics
mean_accuracy = np.mean(accuracies)
std_accuracy = np.std(accuracies)
mean_roc_auc = np.mean(roc_aucs)
std_roc_auc = np.std(roc_aucs)

print("\nCross-Validation Results:")
print(f"Mean Accuracy: {mean_accuracy:.4f}")
print(f"Standard Deviation of Accuracy: {std_accuracy:.4f}")
print(f"Mean ROC-AUC: {mean_roc_auc:.4f}")
print(f"Standard Deviation of ROC-AUC: {std_roc_auc:.4f}")

# Display all confusion matrices
for i, cm in enumerate(confusion_matrices, 1):
    print(f"\nConfusion Matrix for Fold {i}:")
    print(cm)
# Out:
# Training Fold 1/5...
# c:\Users\karan\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 54s 173ms/step - accuracy: 0.5495 - loss: 2.0384 - val_accuracy: 0.5105 - val_loss: 2.5111 - learning_rate: 0.0010
# Epoch 2/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 28s 159ms/step - accuracy: 0.6652 - loss: 1.2051 - val_accuracy: 0.5951 - val_loss: 2.1309 - learning_rate: 0.0010
# Epoch 3/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.7841 - loss: 0.9220 - val_accuracy: 0.7628 - val_loss: 1.0401 - learning_rate: 0.0010
# Epoch 4/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.8333 - loss: 0.8638 - val_accuracy: 0.8315 - val_loss: 0.8716 - learning_rate: 0.0010
# Epoch 5/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 27s 157ms/step - accuracy: 0.8715 - loss: 0.8076 - val_accuracy: 0.8554 - val_loss: 0.8042 - learning_rate: 0.0010
# Epoch 6/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 27s 158ms/step - accuracy: 0.8736 - loss: 0.7676 - val_accuracy: 0.8915 - val_loss: 0.7421 - learning_rate: 0.0010
# Epoch 7/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.8867 - loss: 0.7612 - val_accuracy: 0.9371 - val_loss: 0.6695 - learning_rate: 0.0010
# Epoch 8/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.8955 - loss: 0.7419 - val_accuracy: 0.8402 - val_loss: 0.8762 - learning_rate: 0.0010
# Epoch 9/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.9017 - loss: 0.7388 - val_accuracy: 0.9277 - val_loss: 0.6730 - learning_rate: 0.0010
# Epoch 10/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 27s 158ms/step - accuracy: 0.9079 - loss: 0.7259 - val_accuracy: 0.9450 - val_loss: 0.6729 - learning_rate: 0.0010
# Epoch 11/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 27s 158ms/step - accuracy: 0.9072 - loss: 0.7431 - val_accuracy: 0.9248 - val_loss: 0.7176 - learning_rate: 0.0010
# Epoch 12/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9046 - loss: 0.7456
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 27s 153ms/step - accuracy: 0.9046 - loss: 0.7456 - val_accuracy: 0.9378 - val_loss: 0.6795 - learning_rate: 0.0010
# Epoch 13/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 22s 128ms/step - accuracy: 0.9352 - loss: 0.6744 - val_accuracy: 0.9501 - val_loss: 0.5689 - learning_rate: 5.0000e-04
# Epoch 14/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.9466 - loss: 0.5662 - val_accuracy: 0.9516 - val_loss: 0.4809 - learning_rate: 5.0000e-04
# Epoch 15/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 28s 159ms/step - accuracy: 0.9516 - loss: 0.4818 - val_accuracy: 0.9378 - val_loss: 0.4858 - learning_rate: 5.0000e-04
# Epoch 16/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 27s 156ms/step - accuracy: 0.9479 - loss: 0.4538 - val_accuracy: 0.9588 - val_loss: 0.4228 - learning_rate: 5.0000e-04
# Epoch 17/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 28s 158ms/step - accuracy: 0.9507 - loss: 0.4340 - val_accuracy: 0.9624 - val_loss: 0.3979 - learning_rate: 5.0000e-04
# Epoch 18/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 28s 159ms/step - accuracy: 0.9581 - loss: 0.4222 - val_accuracy: 0.9732 - val_loss: 0.3723 - learning_rate: 5.0000e-04
# Epoch 19/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 27s 156ms/step - accuracy: 0.9529 - loss: 0.4196 - val_accuracy: 0.9711 - val_loss: 0.3816 - learning_rate: 5.0000e-04
# Epoch 20/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 27s 157ms/step - accuracy: 0.9560 - loss: 0.4210 - val_accuracy: 0.9631 - val_loss: 0.3950 - learning_rate: 5.0000e-04
# Epoch 21/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 27s 158ms/step - accuracy: 0
# Epoch 27/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 22s 125ms/step - accuracy: 0.9543 - loss: 0.4249 - val_accuracy: 0.9682 - val_loss: 0.4088 - learning_rate: 5.0000e-04
# Epoch 28/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 20s 115ms/step - accuracy: 0.9585 - loss: 0.4386 - val_accuracy: 0.9768 - val_loss: 0.4062 - learning_rate: 5.0000e-04
# Epoch 29/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 19s 111ms/step - accuracy: 0.9547 - loss: 0.4371 - val_accuracy: 0.9718 - val_loss: 0.4050 - learning_rate: 5.0000e-04
# Epoch 30/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 19s 111ms/step - accuracy: 0.9564 - loss: 0.4450 - val_accuracy: 0.9689 - val_loss: 0.4073 - learning_rate: 5.0000e-04
# Epoch 31/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9564 - loss: 0.4388
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 20s 115ms/step - accuracy: 0.9564 - loss: 0.4389 - val_accuracy: 0.9740 - val_loss: 0.4064 - learning_rate: 5.0000e-04
# Epoch 32/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 21s 120ms/step - accuracy: 0.9576 - loss: 0.4328 - val_accuracy: 0.9768 - val_loss: 0.3680 - learning_rate: 2.5000e-04
# Epoch 33/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 20s 118ms/step - accuracy: 0.9762 - loss: 0.3697 - val_accuracy: 0.9740 - val_loss: 0.3470 - learning_rate: 2.5000e-04
# Epoch 34/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 22s 124ms/step - accuracy: 0.9791 - loss: 0.3349 - val_accuracy: 0.9747 - val_loss: 0.3179 - learning_rate: 2.5000e-04
# Epoch 35/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 21s 120ms/step - accuracy: 0.9785 - loss: 0.3083 - val_accuracy: 0.9761 - val_loss: 0.3076 - learning_rate: 2.5000e-04
# Epoch 36/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 21s 124ms/step - accuracy: 0.9781 - loss: 0.2933 - val_accuracy: 0.9754 - val_loss: 0.2831 - learning_rate: 2.5000e-04
# Epoch 37/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 20s 115ms/step - accuracy: 0.9764 - loss: 0.2873 - val_accuracy: 0.9732 - val_loss: 0.2837 - learning_rate: 2.5000e-04
# Epoch 38/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 20s 117ms/step - accuracy: 0.9765 - loss: 0.2720 - val_accuracy: 0.9761 - val_loss: 0.2681 - learning_rate: 2.5000e-04
# Epoch 39/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 21s 118ms/step - accuracy: 0.9761 - loss: 0.2726 - val_accuracy: 0.9740 - val_loss: 0.2715 - learning_rate: 2.5000e-04
# Epoch 40/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 21s 122ms/step - accuracy: 0.9788 - loss: 0.2562 - val_accuracy: 0.9718 - val_loss: 0.2596 - learning_rate: 2.5000e-04
# Epoch 41/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 21s 121ms/step - accuracy: 0.9779 - loss: 0.2534 - val_accuracy: 0.9761 - val_loss: 0.2522 - learning_rate: 2.5000e-04
# Epoch 42/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 21s 120ms/step - accuracy: 0.9779 - loss: 0.2628 - val_accuracy: 0.9725 - val_loss: 0.2573 - learning_rate: 2.5000e-04
# Epoch 43/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 14s 80ms/step - accuracy: 0.9754 - loss: 0.2512 - val_accuracy: 0.9761 - val_loss: 0.2478 - learning_rate: 2.5000e-04
# Epoch 44/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 14s 82ms/step - accuracy: 0.9800 - loss: 0.2434 - val_accuracy: 0.9768 - val_loss: 0.2523 - learning_rate: 2.5000e-04
# Epoch 45/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 14s 83ms/step - accuracy: 0.9741 - loss: 0.2579 - val_accuracy: 0.9732 - val_loss: 0.2576 - learning_rate: 2.5000e-04
# Epoch 46/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 14s 80ms/step - accuracy: 0.9708 - loss: 0.2580 - val_accuracy: 0.9732 - val_loss: 0.2532 - learning_rate: 2.5000e-04
# Epoch 47/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 14s 81ms/step - accuracy: 0.9747 - loss: 0.2460 - val_accuracy: 0.9754 - val_loss: 0.2478 - learning_rate: 2.5000e-04
# Epoch 48/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9745 - loss: 0.2531
# Epoch 48: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 14s 80ms/step - accuracy: 0.9745 - loss: 0.2531 - val_accuracy: 0.9725 - val_loss: 0.2599 - learning_rate: 2.5000e-04
# Epoch 49/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 14s 79ms/step - accuracy: 0.9806 - loss: 0.2423 - val_accuracy: 0.9711 - val_loss: 0.2479 - learning_rate: 1.2500e-04
# Epoch 50/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 14s 80ms/step - accuracy: 0.9847 - loss: 0.2266 - val_accuracy: 0.9718 - val_loss: 0.2410 - learning_rate: 1.2500e-04
# Restoring model weights from the end of the best epoch: 50.
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step
# Fold 3 Accuracy: 0.9718, ROC-AUC: 0.9985
# Confusion Matrix:
# [[655  36]
#  [  3 688]]
#
# Training Fold 4/5...
# c:\Users\karan\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 19s 84ms/step - accuracy: 0.5353 - loss: 2.1951 - val_accuracy: 0.5695 - val_loss: 1.4485 - learning_rate: 0.0010
# Epoch 2/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 14s 80ms/step - accuracy: 0
# Epoch 31/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 14s 82ms/step - accuracy: 0.9582 - loss: 0.4078 - val_accuracy: 0.9740 - val_loss: 0.3799 - learning_rate: 5.0000e-04
# Epoch 32/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 13s 75ms/step - accuracy: 0.9644 - loss: 0.4032 - val_accuracy: 0.9544 - val_loss: 0.4050 - learning_rate: 5.0000e-04
# Epoch 33/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 13s 78ms/step - accuracy: 0.9629 - loss: 0.4003 - val_accuracy: 0.9486 - val_loss: 0.4342 - learning_rate: 5.0000e-04
# Epoch 34/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 14s 83ms/step - accuracy: 0.9539 - loss: 0.4240 - val_accuracy: 0.9732 - val_loss: 0.3762 - learning_rate: 5.0000e-04
# Epoch 35/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 16s 90ms/step - accuracy: 0.9554 - loss: 0.4120 - val_accuracy: 0.9768 - val_loss: 0.3690 - learning_rate: 5.0000e-04
# Epoch 36/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 87ms/step - accuracy: 0.9581 - loss: 0.4131 - val_accuracy: 0.9580 - val_loss: 0.4326 - learning_rate: 5.0000e-04
# Epoch 37/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 86ms/step - accuracy: 0.9490 - loss: 0.4375 - val_accuracy: 0.9544 - val_loss: 0.4297 - learning_rate: 5.0000e-04
# Epoch 38/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 85ms/step - accuracy: 0.9596 - loss: 0.4170 - val_accuracy: 0.9696 - val_loss: 0.3943 - learning_rate: 5.0000e-04
# Epoch 39/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 84ms/step - accuracy: 0.9577 - loss: 0.4142 - val_accuracy: 0.9790 - val_loss: 0.3890 - learning_rate: 5.0000e-04
# Epoch 40/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9577 - loss: 0.4251
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 84ms/step - accuracy: 0.9577 - loss: 0.4251 - val_accuracy: 0.9754 - val_loss: 0.3851 - learning_rate: 5.0000e-04
# Epoch 41/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 85ms/step - accuracy: 0.9573 - loss: 0.4206 - val_accuracy: 0.9776 - val_loss: 0.3549 - learning_rate: 2.5000e-04
# Epoch 42/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 85ms/step - accuracy: 0.9648 - loss: 0.3688 - val_accuracy: 0.9761 - val_loss: 0.3320 - learning_rate: 2.5000e-04
# Epoch 43/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 84ms/step - accuracy: 0.9772 - loss: 0.3255 - val_accuracy: 0.9776 - val_loss: 0.3042 - learning_rate: 2.5000e-04
# Epoch 44/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 84ms/step - accuracy: 0.9806 - loss: 0.3000 - val_accuracy: 0.9783 - val_loss: 0.2921 - learning_rate: 2.5000e-04
# Epoch 45/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 84ms/step - accuracy: 0.9803 - loss: 0.2870 - val_accuracy: 0.9826 - val_loss: 0.2658 - learning_rate: 2.5000e-04
# Epoch 46/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 84ms/step - accuracy: 0.9799 - loss: 0.2683 - val_accuracy: 0.9718 - val_loss: 0.2820 - learning_rate: 2.5000e-04
# Epoch 47/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 14s 83ms/step - accuracy: 0.9787 - loss: 0.2581 - val_accuracy: 0.9776 - val_loss: 0.2559 - learning_rate: 2.5000e-04
# Epoch 48/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 14s 83ms/step - accuracy: 0.9796 - loss: 0.2508 - val_accuracy: 0.9797 - val_loss: 0.2430 - learning_rate: 2.5000e-04
# Epoch 49/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 84ms/step - accuracy: 0.9776 - loss: 0.2476 - val_accuracy: 0.9754 - val_loss: 0.2589 - learning_rate: 2.5000e-04
# Epoch 50/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 85ms/step - accuracy: 0.9818 - loss: 0.2362 - val_accuracy: 0.9776 - val_loss: 0.2400 - learning_rate: 2.5000e-04
# Restoring model weights from the end of the best epoch: 50.
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step
# Fold 4 Accuracy: 0.9776, ROC-AUC: 0.9997
# Confusion Matrix:
# [[660  31]
#  [  0 691]]
#
# Training Fold 5/5...
# c:\Users\karan\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 20s 90ms/step - accuracy: 0.5441 - loss: 2.0358 - val_accuracy: 0.5818 - val_loss: 1.3525 - learning_rate: 0.0010
# Epoch 2/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 86ms/step - accuracy: 0.6269 - loss: 1.2239 - val_accuracy: 0.7127 - val_loss: 0.9861 - learning_rate: 0.0010
# Epoch 3/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 85ms/step - accuracy: 0.7562 - loss: 0.8981 - val_accuracy: 0.7344 - val_loss: 1.0156 - learning_rate: 0.0010
# Epoch 4/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 84ms/step - accuracy: 0.8019 - loss: 0.8004 - val_accuracy: 0.8097 - val_loss: 0.7721 - learning_rate: 0.0010
# Epoch 5/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 85ms/step - accuracy: 0.8329 - loss: 0.7438 - val_accuracy: 0.8394 - val_loss: 0.7697 - learning_rate: 0.0010
# Epoch 6/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 85ms/step - accuracy: 0.8670 - loss: 0.7334 - val_accuracy: 0.8907 - val_loss: 0.7146 - learning_rate: 0.0010
# Epoch 7/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 85ms/step - accuracy: 0.8778 - loss: 0.7267 - val_accuracy: 0.9204 - val_loss: 0.6646 - learning_rate: 0.0010
# Epoch 8/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 86ms/step - accuracy: 0.8879 - loss: 0.7305 - val_accuracy: 0.9233 - val_loss: 0.6803 - learning_rate: 0.0010
# Epoch 9/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 85ms/step - accuracy: 0.8901 - loss: 0.7405 - val_accuracy: 0.9190 - val_loss: 0.6875 - learning_rate: 0.0010
# Epoch 10/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 85ms/step - accuracy: 0.8947 - loss: 0.7102 - val_accuracy: 0.9443 - val_loss: 0.6678 - learning_rate: 0.0010
# Epoch 11/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 86ms/step - accuracy: 0.9101 - loss: 0.7123 - val_accuracy: 0.9204 - val_loss: 0.7088 - learning_rate: 0.0010
# Epoch 12/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 87ms/step - accuracy: 0.9104 - loss: 0.7158 - val_accuracy: 0.9544 - val_loss: 0.6607 - learning_rate: 0.0010
# Epoch 13/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 87ms/step - accuracy: 0.9042 - loss: 0.7497 - val_accuracy: 0.9182 - val_loss: 0.6965 - learning_rate: 0.0010
# Epoch 14/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 87ms/step - accuracy: 0.9025 - loss: 0.7446 - val_accuracy: 0.9110 - val_loss: 0.7109 - learning_rate: 0.0010
# Epoch 15/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 88ms/step - accuracy: 0.9105 - loss: 0.6976 - val_accuracy: 0.9414 - val_loss: 0.6486 - learning_rate: 0.0010
# Epoch 16/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 89ms/step - accuracy: 0.9160 - loss: 0.6988 - val_accuracy: 0.9421 - val_loss: 0.6424 - learning_rate: 0.0010
# Epoch 17/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 88ms/step - accuracy: 0.9231 - loss: 0.6754 - val_accuracy: 0.9356 - val_loss: 0.6875 - learning_rate: 0.0010
# Epoch 18/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 16s 89ms/step - accuracy: 0.9181 - loss: 0.6987 - val_accuracy: 0.9609 - val_loss: 0.6433 - learning_rate: 0.0010
# Epoch 19/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 16s 90ms/step - accuracy: 0.9171 - loss: 0.7081 - val_accuracy: 0.9276 - val_loss: 0.7036 - learning_rate: 0.0010
# Epoch 20/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 86ms/step - accuracy: 0.9189 - loss: 0.6955 - val_accuracy: 0.9551 - val_loss: 0.6342 - learning_rate: 0.0010
# Epoch 21/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 89ms/step - accuracy: 0.9285 - loss: 0.6610 - val_accuracy: 0.9204 - val_loss: 0.7387 - learning_rate: 0.0010
# Epoch 22/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 87ms/step - accuracy: 0.9195 - loss: 0.7047 - val_accuracy: 0.9638 - val_loss: 0.6512 - learning_rate: 0.0010
# Epoch 23/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 86ms/step - accuracy: 0.9188 - loss: 0.6984 - val_accuracy: 0.9667 - val_loss: 0.6210 - learning_rate: 0.0010
# Epoch 24/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 87ms/step - accuracy: 0.9303 - loss: 0.6557 - val_accuracy: 0.9385 - val_loss: 0.6615 - learning_rate: 0.0010
# Epoch 25/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 89ms/step - accuracy: 0.9238 - loss: 0.6651 - val_accuracy: 0.9696 - val_loss: 0.6009 - learning_rate: 0.0010
# Epoch 26/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 16s 90ms/step - accuracy: 0.9211 - loss: 0.6569 - val_accuracy: 0.9645 - val_loss: 0.6209 - learning_rate: 0.0010
# Epoch 27/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 86ms/step - accuracy: 0.9288 - loss: 0.6594 - val_accuracy: 0.9284 - val_loss: 0.7432 - learning_rate: 0.0010
# Epoch 28/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 85ms/step - accuracy: 0.9209 - loss: 0.6966 - val_accuracy: 0.9262 - val_loss: 0.7532 - learning_rate: 0.0010
# Epoch 29/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 86ms/step - accuracy: 0.9221 - loss: 0.7131 - val_accuracy: 0.9595 - val_loss: 0.6388 - learning_rate: 0.0010
# Epoch 30/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9308 - loss: 0.6778
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 85ms/step - accuracy: 0.9308 - loss: 0.6779 - val_accuracy: 0.9718 - val_loss: 0.6041 - learning_rate: 0.0010
# Epoch 31/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 84ms/step - accuracy: 0.9360 - loss: 0.6252 - val_accuracy: 0.9696 - val_loss: 0.5506 - learning_rate: 5.0000e-04
# Epoch 32/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 85ms/step - accuracy: 0.9546 - loss: 0.5190 - val_accuracy: 0.9790 - val_loss: 0.4606 - learning_rate: 5.0000e-04
# Epoch 33/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 84ms/step - accuracy: 0.9553 - loss: 0.4495 - val_accuracy: 0.9761 - val_loss: 0.4130 - learning_rate: 5.0000e-04
# Epoch 34/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 84ms/step - accuracy: 0.9657 - loss: 0.4148 - val_accuracy: 0.9776 - val_loss: 0.3940 - learning_rate: 5.0000e-04
# Epoch 35/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 85ms/step - accuracy: 0.9591 - loss: 0.4140 - val_accuracy: 0.9761 - val_loss: 0.3831 - learning_rate: 5.0000e-04
# Epoch 36/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 84ms/step - accuracy: 0.9591 - loss: 0.4012 - val_accuracy: 0.9660 - val_loss: 0.4069 - learning_rate: 5.0000e-04
# Epoch 37/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 85ms/step - accuracy: 0.9585 - loss: 0.3922 - val_accuracy: 0.9754 - val_loss: 0.3990 - learning_rate: 5.0000e-04
# Epoch 38/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 87ms/step - accuracy: 0.9587 - loss: 0.3878 - val_accuracy: 0.9761 - val_loss: 0.3934 - learning_rate: 5.0000e-04
# Epoch 39/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 16s 89ms/step - accuracy: 0.9556 - loss: 0.3968 - val_accuracy: 0.9819 - val_loss: 0.3733 - learning_rate: 5.0000e-04
# Epoch 40/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 88ms/step - accuracy: 0.9569 - loss: 0.3974 - val_accuracy: 0.9747 - val_loss: 0.4071 - learning_rate: 5.0000e-04
# Epoch 41/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 86ms/step - accuracy: 0.9600 - loss: 0.3986 - val_accuracy: 0.9718 - val_loss: 0.4266 - learning_rate: 5.0000e-04
# Epoch 42/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 86ms/step - accuracy: 0.9654 - loss: 0.3943 - val_accuracy: 0.9776 - val_loss: 0.3921 - learning_rate: 5.0000e-04
# Epoch 43/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 87ms/step - accuracy: 0.9639 - loss: 0.3908 - val_accuracy: 0.9718 - val_loss: 0.4098 - learning_rate: 5.0000e-04
# Epoch 44/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9570 - loss: 0.4057
# Epoch 44: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 86ms/step - accuracy: 0.9570 - loss: 0.4057 - val_accuracy: 0.9819 - val_loss: 0.3876 - learning_rate: 5.0000e-04
# Epoch 45/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 86ms/step - accuracy: 0.9633 - loss: 0.3768 - val_accuracy: 0.9826 - val_loss: 0.3661 - learning_rate: 2.5000e-04
# Epoch 46/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 87ms/step - accuracy: 0.9730 - loss: 0.3394 - val_accuracy: 0.9819 - val_loss: 0.3477 - learning_rate: 2.5000e-04
# Epoch 47/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 85ms/step - accuracy: 0.9793 - loss: 0.3058 - val_accuracy: 0.9826 - val_loss: 0.3272 - learning_rate: 2.5000e-04
# Epoch 48/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 85ms/step - accuracy: 0.9817 - loss: 0.2808 - val_accuracy: 0.9790 - val_loss: 0.3147 - learning_rate: 2.5000e-04
# Epoch 49/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 85ms/step - accuracy: 0.9775 - loss: 0.2735 - val_accuracy: 0.9812 - val_loss: 0.3033 - learning_rate: 2.5000e-04
# Epoch 50/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 15s 86ms/step - accuracy: 0.9786 - loss: 0.2617 - val_accuracy: 0.9826 - val_loss: 0.2762 - learning_rate: 2.5000e-04
# Restoring model weights from the end of the best epoch: 50.
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
# Fold 5 Accuracy: 0.9826, ROC-AUC: 0.9921
# Confusion Matrix:
# [[667  24]
#  [  0 691]]
#
# Cross-Validation Results:
# Mean Accuracy: 0.9810
# Standard Deviation of Accuracy: 0.0058
# Mean ROC-AUC: 0.9975
# Standard Deviation of ROC-AUC: 0.0029
#
# Confusion Matrix for Fold 1:
# [[676  16]
#  [  0 691]]
#
# Confusion Matrix for Fold 2:
# [[670  21]
#  [  0 692]]
#
# Confusion Matrix for Fold 3:
# [[655  36]
#  [  3 688]]
#
# Confusion Matrix for Fold 4:
# [[660  31]
#  [  0 691]]
#
# Confusion Matrix for Fold 5:
# [[667  24]
#  [  0 691]]
